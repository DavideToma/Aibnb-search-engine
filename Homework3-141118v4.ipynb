# %% [markdown]
# # HOMEWORK 3

# %%
def install(package):
    try:
        import subprocess
        import sys
        subprocess.call([sys.executable, "-m", "pip", "install", package])
        print("Library installed")
    except:
        print("Cannot install the library")

# %%
try:
    from langdetect import detect
except:
    print("The library LanfDetect is not in the repository, I will install it")
    install('langdetect')
    from langdetect import detect

try:
    from texttable import Texttable
except:
    print("The library TextTable is not in the repository, I will install it")
    install('texttable')
    from texttable import Texttable

# %%
import pandas as pd
import unicodecsv as csv # We also import the unicodecsv library to handle any Unicode objects in the CSV report...as csv.
import nltk
import string

from nltk import word_tokenize
from nltk.corpus import stopwords
from langdetect import detect

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/fabiomontello/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# STEP 1 - DATA

# %%
DIR = 'data/docs/' # C:/Users/david/Desktop/DATA SCIENCE/AMD/documents/

df = pd.read_csv("data/Airbnb_Texas_Rentals.csv", sep=",") # we read the dataset

# %%
df = df.drop('Unnamed: 0',axis = 1) #this column is useless for our analisys
df = df[pd.notnull((df['description'])) & (df['description'] != "\\" ) & (df['description'] != "." )] #If the row has no description, for us is useless, so we drop it
df = df.replace(r'\\n',' ', regex=True) #Remove all the new lines in the dataframe
df['language'] = 'nd'
df.head()
# Out:
#   average_rate_per_night bedrooms_count         city date_of_listing  \
# 0                    $27              2       Humble        May 2016
# 1                   $149              4  San Antonio   November 2010
# 2                    $59              1      Houston    January 2017
# 3                    $60              1        Bryan   February 2016
# 4                    $75              2   Fort Worth   February 2017
#
#                                          description   latitude  longitude  \
# 0  Welcome to stay in private room with queen bed...  30.020138 -95.293996
# 1  Stylish, fully remodeled home in upscale NW – ...  29.503068 -98.447688
# 2  'River house on island close to the city' A we...  29.829352 -95.081549
# 3  Private bedroom in a cute little home situated...  30.637304 -96.337846
# 4  Welcome to our original 1920's home. We recent...  32.747097 -97.286434
#
#                                                title  \
# 0    2 Private rooms/bathroom 10min from IAH airport
# 1  Unique Location! Alamo Heights - Designer Insp...
# 2                          River house near the city
# 3                       Private Room Close to Campus
# 4                                          The Porch
#
#                                                  url language
# 0  https://www.airbnb.com/rooms/18520444?location...       nd
# 1  https://www.airbnb.com/rooms/17481455?location...       nd
# 2  https://www.airbnb.com/rooms/16926307?location...       nd
# 3  https://www.airbnb.com/rooms/11839729?location...       nd
# 4  https://www.airbnb.com/rooms/17325114?location...       nd

# %% [markdown]
# STEP 2 - WRITE DOCUMENTS

# %%
for row in df.iterrows():
    file_name = DIR + 'doc_'+str(row[0])+'.tsv'
    with open(file_name,'wb') as file: # the wb means we are writing a file in binary mode.
        csv_writer = csv.writer(file, delimiter = '\t') #now we are writing the files as tab separated files.
        csv_writer.writerow(list(row[1].values)) #writerow want a list object ad input, so we used list.
        file.close() #Once the file is written, we close it, so we free some memory

# %%
docdict = {}

languages = {'en': 'english', 'de': 'german', 'es': 'spanish', 'nl': 'dutch'}

for i, row in df[:].iterrows(): #We limit to 5 just to work quickly

    #Remove punctuation
    text = str(row['description']).translate({key: None for key in string.punctuation}) + ' '+ str(row['title']).translate({key: None for key in string.punctuation})
    
    if(text):
        try:
            lan = detect(str(text))
            if (lan in languages):
                languages[lan]
        
                #The text here is Spanish, we can decide what to do
                df.loc[i,'language'] = lan
        
                #Remove all the stopwords and all the non alphabetic words
                tostem = ([x.lower() for x in text.split(' ') if x.lower() not in stopwords.words(languages[lan]) and x.isalpha()])
        
                #Stem all the words
                docdict[i] = [nltk.stem.SnowballStemmer(languages[lan]).stem(word) for word in tostem]
            else:
                pass
        except:
            pass

# languages
docdict
# Out:
# {0: ['welcom',
#   'stay',
#   'privat',
#   'room',
#   'queen',
#   'bed',
#   'detach',
#   'privat',
#   'bathroom',
#   'second',
#   'anoth',
#   'privat',
#   'bedroom',
#   'sofa',
#   'bed',
#   'avail',
#   'addit',
#   'addit',
#   'iah',
#   'airportairport',
#   'avail',
#   'privat',
#   'iah',
#   'airport'],
#  1: ['fulli',
#   'remodel',
#   'home',
#   'upscal',
#   'nw',
#   'alamo',
#   'height',
#   'amaz',
#   'locat',
#   'hous',
#   'conveni',
#   'locat',
#   'quiet',
#   'beauti',
#   'season',
#   'prestigi',
#   'neighborhood',
#   'close',
#   'loop',
#   'featur',
#   'open',
#   'floor',
#   'origin',
#   'hardwood',
#   'full',
#   'bathroom',
#   'independ',
#   'room',
#   'sleep',
#   'moreeuropean',
#   'inspir',
#   'kitchen',
#   'driveway',
#   'park',
#   'uniqu',
#   'alamo',
#   'height',
#   'design',
#   'inspir'],
#  2: ['hous',
#   'island',
#   'close',
#   'well',
#   'maintain',
#   'river',
#   'hous',
#   'san',
#   'jacinto',
#   'river',
#   'extra',
#   'room',
#   'temporari',
#   'river',
#   'hous',
#   'near',
#   'citi'],
#  3: ['privat',
#   'bedroom',
#   'cute',
#   'littl',
#   'home',
#   'situat',
#   'covet',
#   'garden',
#   'acr',
#   'neighborhood',
#   'bedroom',
#   'privat',
#   'access',
#   'privat',
#   'privat',
#   'room',
#   'close',
#   'campus'],
#  4: ['welcom',
#   'origin',
#   'recent',
#   'purchas',
#   'home',
#   'mile',
#   'outsid',
#   'downtown',
#   'fort',
#   'worth',
#   'happi',
#   'restor',
#   'origin',
#   'charact',
#   'home',
#   'built',
#   'minut',
#   'drive',
#   'downtown',
#   'offer',
#   'across',
#   'street',
#   'current',
#   'rejuven',
#   'gateway',
#   'porch'],
#  5: ['place',
#   'close',
#   'lake',
#   'love',
#   'place',
#   'outdoor',
#   'space',
#   'place',
#   'good',
#   'solo',
#   'busi',
#   'famili',
#   'big',
#   'gorgeous',
#   'home',
#   'countri',
#   'set'],
#  6: ['rustic',
#   'countri',
#   'retreat',
#   'acr',
#   'southeast',
#   'convert',
#   'modular',
#   'home',
#   'amen',
#   'need',
#   'offer',
#   'texa',
#   'less',
#   'mile',
#   'austin',
#   'circuit',
#   'america',
#   'formula',
#   'trailer',
#   'park',
#   'avail',
#   'cozi',
#   'quaint',
#   'countri',
#   'retreat'],
#  7: ['beauti',
#   'bedroom',
#   'queen',
#   'size',
#   'bed',
#   'pet',
#   'hous',
#   'alway',
#   'bathroom',
#   'share',
#   'suppli',
#   'towel',
#   'shampoo',
#   'mile',
#   'friend',
#   'privat',
#   'room',
#   'neighborhood'],
#  8: ['first',
#   'class',
#   'comfort',
#   'condo',
#   'best',
#   'view',
#   'bottom',
#   'deck',
#   'master',
#   'bedroom',
#   'step',
#   'away',
#   'bayfront',
#   'condo'],
#  9: ['privat', 'entranc', 'cozi', 'histor', 'privat', 'studio'],
#  10: ['cool',
#   'comfort',
#   'bedroom',
#   'apart',
#   'feel',
#   'like',
#   'comfort',
#   'fit',
#   'peopl',
#   'central',
#   'locat',
#   'quiet',
#   'enjoy',
#   'gourmet',
#   'kitchen',
#   'easi',
#   'access',
#   'major',
#   'cozi',
#   'pool'],
#  11: ['gate',
#   'estat',
#   'heart',
#   'dfw',
#   'set',
#   'wood',
#   'home',
#   'overlook',
#   'beauti',
#   'min',
#   'dfw',
#   'airport',
#   'min',
#   'love',
#   'field',
#   'locat',
#   'minut',
#   'away',
#   'dalla',
#   'fort',
#   'american',
#   'airlin',
#   'dalla',
#   'deep',
#   'global',
#   'life',
#   'six',
#   'fort',
#   'worth',
#   'stock',
#   'texa',
#   'motor',
#   'speed',
#   'grapevin',
#   'mill',
#   'gaylord',
#   'great',
#   'wolf',
#   'check',
#   'list',
#   'home',
#   'fabeuless',
#   'hideaway',
#   'quiet',
#   'cozi',
#   'room'],
#  12: ['place',
#   'combin',
#   'conveni',
#   'visit',
#   'austin',
#   'also',
#   'far',
#   'madden',
#   'peac',
#   'quiet',
#   'view',
#   'die',
#   'natur',
#   'spade',
#   'hum',
#   'bird',
#   'come',
#   'cypress',
#   'creek',
#   'retreat',
#   'hamilton',
#   'pool'],
#  13: ['home',
#   'north',
#   'side',
#   'san',
#   'minut',
#   'away',
#   'great',
#   'golf',
#   'cours',
#   'jw',
#   'marriott',
#   'resort',
#   'great',
#   'stop',
#   'place',
#   'famili',
#   'come',
#   'amen',
#   'internet',
#   'laundri',
#   'room',
#   'hous',
#   'green',
#   'belt',
#   'enjoy',
#   'back',
#   'yard',
#   'area',
#   'safe',
#   'neighbor',
#   'also',
#   'hope',
#   'enjoy',
#   'stay',
#   'enjoy',
#   'san',
#   'cozi',
#   'home',
#   'beauti',
#   'natur',
#   'view'],
#  14: ['place',
#   'close',
#   'downtown',
#   'beauti',
#   'pine',
#   'ceil',
#   'cozi',
#   'cottag',
#   'appeal',
#   'uniqu',
#   'eclect',
#   'kerrvill',
#   'screen',
#   'porch',
#   'huge',
#   'washer',
#   'dryer',
#   'avail',
#   'also',
#   'great',
#   'place',
#   'use',
#   'home',
#   'base',
#   'explor',
#   'texa',
#   'wine',
#   'countri',
#   'cover',
#   'carport',
#   'park',
#   'space',
#   'includ',
#   'rental',
#   'great',
#   'get',
#   'rain',
#   'bad',
#   'car',
#   'cozi',
#   'cottag'],
#  15: ['new', 'hous', 'hint', 'texa', 'countri', 'bedroom', 'bath', 'great'],
#  16: ['cute',
#   'two',
#   'bedroom',
#   'lot',
#   'sunni',
#   'back',
#   'front',
#   'porch',
#   'friend',
#   'neighborhood',
#   'near',
#   'ut',
#   'easi',
#   'walk',
#   'coffe',
#   'shop',
#   'cosi',
#   'bedroom',
#   'hyde'],
#  17: ['place',
#   'close',
#   'restaur',
#   'great',
#   'place',
#   'good',
#   'solo',
#   'busi',
#   'ocean',
#   'getaway',
#   'magnific',
#   'view'],
#  18: ['bedroom',
#   'bathroom',
#   'home',
#   'open',
#   'floor',
#   'plan',
#   'great',
#   'entertain',
#   'locat',
#   'quiet',
#   'neighborhood',
#   'conveni',
#   'locat',
#   'beltway',
#   'super',
#   'bowl',
#   'bdrm',
#   'home',
#   'retreat'],
#  19: ['uniqu',
#   'lakefront',
#   'area',
#   'perfect',
#   'creat',
#   'wonder',
#   'memori',
#   'friend',
#   'locat',
#   'right',
#   'outsid',
#   'citi',
#   'less',
#   'minut',
#   'shop',
#   'yet',
#   'cozi',
#   'relax',
#   'lake',
#   'lewisvill',
#   'lakefront',
#   'conveni',
#   'frisco'],
#  20: ['bedroom',
#   'bath',
#   'sleep',
#   'theater',
#   'room',
#   'plus',
#   'luxuri',
#   'car',
#   'new',
#   'super',
#   'bowl',
#   'hous',
#   'luxuri',
#   'car'],
#  21: ['nice',
#   'bathroom',
#   'home',
#   'beauti',
#   'castleg',
#   'inch',
#   'flat',
#   'screen',
#   'live',
#   'room',
#   'main',
#   'clean',
#   'home',
#   'ampl',
#   'room',
#   'host',
#   'peopl',
#   'set',
#   'ping',
#   'pong',
#   'tabl',
#   'garag',
#   'request',
#   'home',
#   'castleg'],
#  22: ['apart',
#   'nice',
#   'famili',
#   'group',
#   'relax',
#   'time',
#   'place',
#   'everyon',
#   'welcom',
#   'use',
#   'pool',
#   'workout',
#   'equip',
#   'home',
#   'also',
#   'offer',
#   'full',
#   'size',
#   'garag',
#   'park',
#   'two',
#   'getaway',
#   'gateway',
#   'apart',
#   'home'],
#  23: ['place',
#   'close',
#   'kati',
#   'mill',
#   'mall',
#   'lacentera',
#   'movi',
#   'restaur',
#   'grand',
#   'love',
#   'place',
#   'neighborhood',
#   'comfi',
#   'outdoor',
#   'place',
#   'good',
#   'busi',
#   'famili',
#   'luxuri',
#   'master',
#   'bedroom',
#   'safe',
#   'quit',
#   'neibourhood'],
#  24: ['convert',
#   'carriag',
#   'hous',
#   'walk',
#   'distanc',
#   'downtown',
#   'denton',
#   'univers',
#   'north',
#   'texa',
#   'dcta',
#   'bus',
#   'stop',
#   'locat',
#   'across',
#   'street',
#   'downtown',
#   'dcta',
#   'train',
#   'station',
#   'mile',
#   'kitchenett',
#   'refriger',
#   'coffe',
#   'murphi',
#   'bed',
#   'loft',
#   'space',
#   'air',
#   'pleas',
#   'use',
#   'caution',
#   'ladder',
#   'histor',
#   'convert',
#   'carriag',
#   'hous'],
#  25: ['bedroom',
#   'bed',
#   'sleep',
#   'pool',
#   'central',
#   'san',
#   'antonio',
#   'min',
#   'river',
#   'walk',
#   'min',
#   'sea',
#   'world',
#   'min',
#   'fiesta',
#   'min',
#   'onsit',
#   'concierg',
#   'rental',
#   'massag',
#   'babysit',
#   'avail',
#   'discount',
#   'chaletazul',
#   'rent',
#   'avail'],
#  26: ['privat',
#   'room',
#   'warm',
#   'famili',
#   'perfect',
#   'busi',
#   'vacat',
#   'extend',
#   'town',
#   'childbirth',
#   'also',
#   'perfect',
#   'place',
#   'king',
#   'size',
#   'bed',
#   'room'],
#  27: ['cozi',
#   'special',
#   'coupl',
#   'busi',
#   'talk',
#   'english',
#   'french',
#   'privat',
#   'room',
#   'kati'],
#  28: ['comfort',
#   'tradit',
#   'interior',
#   'furnitur',
#   'amaz',
#   'locat',
#   'minut',
#   'drive',
#   'walk',
#   'sola',
#   'eateri',
#   'coffe',
#   'larg',
#   'queen',
#   'bed',
#   'sofa',
#   'doubl',
#   'bed',
#   'comfort',
#   'accommod',
#   'free',
#   'cabl',
#   'tv',
#   'reserv',
#   'fabul',
#   'central',
#   'austin'],
#  29: ['upstair',
#   'stair',
#   'bed',
#   'great',
#   'super',
#   'bowl',
#   'gate',
#   'communiti',
#   'serious',
#   'inquiri',
#   'luxuri',
#   'th',
#   'min',
#   'downtown'],
#  30: ['beauti',
#   'home',
#   'locat',
#   'nice',
#   'conveni',
#   'communiti',
#   'north',
#   'plano',
#   'best',
#   'school',
#   'stay',
#   'peac',
#   'prepar',
#   'everyth',
#   'brand',
#   'new',
#   'find',
#   'everyth',
#   'hotel',
#   'provid',
#   'much',
#   'high',
#   'speed',
#   'wifi',
#   'fast',
#   'speed',
#   'inch',
#   'smart',
#   'local',
#   'doubl',
#   'outdoor',
#   'studi',
#   'good',
#   'busi',
#   'famili',
#   'big',
#   'book',
#   'fulli',
#   'renov',
#   'vacat',
#   'home',
#   'north',
#   'plano'],
#  31: ['great',
#   'space',
#   'couch',
#   'surf',
#   'lot',
#   'avail',
#   'space',
#   'live',
#   'room',
#   'minut',
#   'drive',
#   'super',
#   'min',
#   'drive',
#   'downtown',
#   'min',
#   'walk',
#   'green',
#   'line',
#   'metro',
#   'rail',
#   'goe',
#   'live',
#   'room',
#   'super',
#   'bowl'],
#  32: ['place',
#   'five',
#   'seven',
#   'minut',
#   'direct',
#   'north',
#   'close',
#   'ballpark',
#   'six',
#   'hurrican',
#   'restaur',
#   'love',
#   'place',
#   'treed',
#   'neighborhood',
#   'near',
#   'park',
#   'comfi',
#   'outdoor',
#   'place',
#   'good',
#   'solo',
#   'busi',
#   'comfi',
#   'garag',
#   'apt',
#   'pool',
#   'close'],
#  33: ['minut',
#   'main',
#   'entir',
#   'sq',
#   'ft',
#   'attach',
#   'apart',
#   'desir',
#   'tarrytown',
#   'neighborhood',
#   'live',
#   'bedroom',
#   'licens',
#   'citi',
#   'austin',
#   'oper',
#   'short',
#   'term',
#   'hotel',
#   'occup',
#   'tax',
#   'includ',
#   'sunni',
#   'central',
#   'austin',
#   'apart'],
#  34: ['bedrol',
#   'bunkhous',
#   'ranch',
#   'nestl',
#   'acr',
#   'beauti',
#   'privat',
#   'come',
#   'friend',
#   'famili',
#   'enjoy',
#   'hors',
#   'shoe',
#   'star',
#   'listen',
#   'coyot',
#   'sit',
#   'read',
#   'star',
#   'night',
#   'amaz'],
#  35: ['come',
#   'relax',
#   'water',
#   'beauti',
#   'beach',
#   'hous',
#   'style',
#   'river',
#   'love',
#   'shiplap',
#   'wall',
#   'view',
#   'even',
#   'monro',
#   'manor'],
#  36: ['place',
#   'close',
#   'sxsw',
#   'venuespoodi',
#   'roadhousepac',
#   'bend',
#   'parkpedernal',
#   'rivermarbl',
#   'fallstexa',
#   'hill',
#   'countryapi',
#   'love',
#   'place',
#   'relax',
#   'canyon',
#   'hike',
#   'pedernal',
#   'river',
#   'play',
#   'launch',
#   'privat',
#   'park',
#   'outdoor',
#   'place',
#   'good',
#   'solo',
#   'busi',
#   'cat',
#   'amethyst',
#   'room',
#   'canyon',
#   'ranch'],
#  37: ['modern',
#   'remodel',
#   'spartan',
#   'larg',
#   'shade',
#   'chic',
#   'spartanett',
#   'guesthous'],
#  38: ['sleep',
#   'laid',
#   'back',
#   'quiet',
#   'plenti',
#   'space',
#   'properti',
#   'caretak',
#   'avail',
#   'excel',
#   'big',
#   'famili',
#   'safeti',
#   'comfort',
#   'main',
#   'ampl',
#   'park',
#   'space',
#   'home',
#   'wheel',
#   'chair',
#   'access',
#   'handicap',
#   'casa',
#   'de',
#   'alexi',
#   'guesthom'],
#  39: ['low',
#   'cost',
#   'motel',
#   'style',
#   'privat',
#   'room',
#   'door',
#   'lock',
#   'key',
#   'need',
#   'schedul',
#   'arriv',
#   'may',
#   'home',
#   'greet',
#   'anytim',
#   'day',
#   'arriv',
#   'keyless',
#   'entri',
#   'door',
#   'wifi',
#   'everyth',
#   'need',
#   'know',
#   'stay',
#   'detail',
#   'email',
#   'airbnb',
#   'reserv',
#   'confirm',
#   'free',
#   'full',
#   'hassl',
#   'free',
#   'independ',
#   'stay',
#   'bicker',
#   'n',
#   'westmoreland',
#   'dalla',
#   'avail',
#   'privat',
#   'movi'],
#  40: ['place', 'close', 'airport', 'citi', 'femal', 'guest'],
#  41: ['comal',
#   'hideway',
#   'nestl',
#   'right',
#   'comal',
#   'direct',
#   'across',
#   'unit',
#   'home',
#   'away',
#   'take',
#   'advantag',
#   'communiti',
#   'grill',
#   'along',
#   'relax',
#   'insid',
#   'spectacular',
#   'view',
#   'make',
#   'next',
#   'vacat',
#   'one',
#   'rememb',
#   'comal',
#   'comal',
#   'across'],
#  42: ['perfect',
#   'home',
#   'rest',
#   'close',
#   'feel',
#   'right',
#   'home',
#   'big',
#   'big',
#   'big',
#   'comfi',
#   'bigger',
#   'full',
#   'access',
#   'outdoor',
#   'patio',
#   'fire',
#   'outdoor',
#   'two',
#   'water',
#   'space',
#   'complet',
#   'renov',
#   'readi',
#   'texa',
#   'style',
#   'eleg'],
#  43: ['clean',
#   'cozi',
#   'brick',
#   'home',
#   'comfort',
#   'room',
#   'guest',
#   'rent',
#   'per',
#   'larg',
#   'backyard',
#   'big',
#   'tree',
#   'tv',
#   'channel',
#   'bed',
#   'case',
#   'comfort',
#   'room',
#   'avail'],
#  44: ['stylish',
#   'updat',
#   'bedroom',
#   'conveni',
#   'locat',
#   'across',
#   'street',
#   'taylor',
#   'counti',
#   'expo',
#   'shotwel',
#   'abilen',
#   'lyle',
#   'land',
#   'cattl',
#   'minut',
#   'abilen',
#   'summon',
#   'home',
#   'away',
#   'home'],
#  45: ['apart',
#   'finish',
#   'high',
#   'peopl',
#   'valu',
#   'apart',
#   'readi',
#   'move',
#   'love',
#   'privat',
#   'room'],
#  46: ['hous',
#   'feel',
#   'like',
#   'stay',
#   'countri',
#   'walk',
#   'ride',
#   'bikeshar',
#   'station',
#   'samuel',
#   'connect',
#   'point',
#   'downtown',
#   'includ',
#   'west',
#   'museum',
#   'triniti',
#   'train',
#   'track',
#   'near',
#   'hous',
#   'provid',
#   'ambient',
#   'nois',
#   'ad',
#   'uniqu',
#   'love',
#   'live',
#   'hous',
#   'renov',
#   'modern',
#   'bungalow',
#   'craftsman',
#   'near',
#   'downtown'],
#  47: ['two',
#   'king',
#   'two',
#   'full',
#   'bed',
#   'second',
#   'sleeper',
#   'sofa',
#   'live',
#   'maximum',
#   'occup',
#   'marbl'],
#  48: ['complet',
#   'renov',
#   'singl',
#   'famili',
#   'home',
#   'super',
#   'bowl',
#   'mile',
#   'minut',
#   'nrg',
#   'full',
#   'access',
#   'larg',
#   'master',
#   'suit',
#   'king',
#   'size',
#   'bed',
#   'addit',
#   'mile',
#   'super',
#   'pool',
#   'full',
#   'access'],
#  49: ['place',
#   'great',
#   'close',
#   'kyle',
#   'georg',
#   'bush',
#   'northgat',
#   'great',
#   'place',
#   'accommod',
#   'great',
#   'price',
#   'coupl',
#   'mani',
#   'reason',
#   'love',
#   'vacat',
#   'rental',
#   'june'],
#  50: ['morn', 'star', 'eleg', 'welcom', 'morn', 'star'],
#  51: ['home',
#   'famili',
#   'orient',
#   'neighborhood',
#   'access',
#   'major',
#   'highway',
#   'mile',
#   'mile',
#   'minut',
#   'dfw',
#   'dalla',
#   'love',
#   'airport',
#   'minut',
#   'downtown',
#   'enjoy',
#   'amaz',
#   'rang',
#   'shop',
#   'within',
#   'minut',
#   'premium',
#   'outlet',
#   'stonebriar',
#   'mall',
#   'watter',
#   'great',
#   'solo',
#   'busi',
#   'travel',
#   'famili',
#   'beauti',
#   'ba',
#   'home',
#   'near',
#   'major',
#   'highway'],
#  52: ['bedroom',
#   'sleep',
#   'twin',
#   'sleeper',
#   'futon',
#   'live',
#   'first',
#   'bedroom',
#   'king',
#   'walk',
#   'electr',
#   'fire',
#   'second',
#   'bedroom',
#   'queen',
#   'size',
#   'full',
#   'kitchen',
#   'linen',
#   'towel',
#   'dish',
#   'window',
#   'downtown',
#   'smoke',
#   'insid',
#   'ferral',
#   'cat',
#   'live',
#   'properti',
#   'hackberri',
#   'hous'],
#  53: ['built',
#   'min',
#   'airport',
#   'quiet',
#   'entir',
#   'second',
#   'stori',
#   'full',
#   'inflat',
#   'queen',
#   'mattress',
#   'min',
#   'away',
#   'downtown',
#   'min',
#   'away',
#   'minut',
#   'away',
#   'groceri',
#   'store',
#   'hr',
#   'emerg',
#   'amen',
#   'includ',
#   'gym',
#   'treadmil',
#   'erg',
#   'german',
#   'shepherd',
#   'limit',
#   'floor',
#   'master',
#   'cozi',
#   'second',
#   'floor',
#   'minut',
#   'iah'],
#  54: ['cozi',
#   'apart',
#   'locat',
#   'downtown',
#   'san',
#   'space',
#   'within',
#   'walk',
#   'distanc',
#   'convent',
#   'hemisfair',
#   'also',
#   'locat',
#   'near',
#   'southtown',
#   'featur',
#   'array',
#   'enjoy',
#   'close',
#   'public',
#   'park',
#   'basebal',
#   'larg',
#   'picnic',
#   'offer',
#   'guest',
#   'free',
#   'pick',
#   'san',
#   'antonio',
#   'intern',
#   'also',
#   'ampl',
#   'street',
#   'use',
#   'downtown',
#   'apart',
#   'locat',
#   'near',
#   'convent',
#   'center'],
#  55: ['entir',
#   'full',
#   'bath',
#   'home',
#   'quiet',
#   'third',
#   'bedroom',
#   'area',
#   'furnish',
#   'offic',
#   'space',
#   'larg',
#   'driveway',
#   'privat',
#   'park',
#   'vehicl',
#   'mile',
#   'famili',
#   'great',
#   'block',
#   'us',
#   'ne',
#   'medic',
#   'medic',
#   'great',
#   'solo',
#   'busi',
#   'thursday',
#   'block',
#   'book',
#   'often',
#   'make',
#   'except',
#   'extend',
#   'entir',
#   'home',
#   'mile',
#   'iah',
#   'block',
#   'hwi'],
#  56: ['cozi',
#   'hous',
#   'locat',
#   'north',
#   'fort',
#   'worth',
#   'safe',
#   'environ',
#   'close',
#   'shop',
#   'conveni',
#   'locat',
#   'fort',
#   'minut',
#   'drive',
#   'allianc',
#   'town',
#   'center',
#   'minut',
#   'drive',
#   'fort',
#   'worth',
#   'long',
#   'term',
#   'singl',
#   'renter',
#   'cozi',
#   'privat',
#   'room',
#   'north',
#   'fort',
#   'worth'],
#  57: ['gorgeous',
#   'home',
#   'offer',
#   'bathroom',
#   'eleg',
#   'plan',
#   'featur',
#   'studi',
#   'room',
#   'equip',
#   'sofa',
#   'gorgeous',
#   'kitchen',
#   'great',
#   'live',
#   'space',
#   'tv',
#   'tailor',
#   'locat',
#   'close',
#   'proxim',
#   'kati',
#   'mill',
#   'shop',
#   'houston',
#   'premium',
#   'typhoon',
#   'water',
#   'energi',
#   'new',
#   'hospit',
#   'sincer',
#   'hope',
#   'wonder',
#   'profit',
#   'stay',
#   'dear',
#   'town',
#   'love',
#   'kati',
#   'home',
#   'fantast',
#   'locat'],
#  58: ['welcom',
#   'happi',
#   'place',
#   'newli',
#   'well',
#   'lit',
#   'furnish',
#   'privat',
#   'bedroom',
#   'tub',
#   'accompani',
#   'closet',
#   'locat',
#   'heart',
#   'las',
#   'great',
#   'neighborhood',
#   'quiet',
#   'surround',
#   'guest',
#   'background',
#   'welcom',
#   'complimentari',
#   'guest',
#   'park',
#   'good',
#   'access',
#   'highway',
#   'luxuri',
#   'privat',
#   'bedroom',
#   'bath',
#   'las',
#   'colina'],
#  59: ['cozi',
#   'mile',
#   'downtown',
#   'conveni',
#   'shop',
#   'clara',
#   'martin',
#   'suit'],
#  60: ['place',
#   'good',
#   'solo',
#   'busi',
#   'famili',
#   'charm',
#   'privat',
#   'room',
#   'gate',
#   'communiti',
#   'kati'],
#  61: ['cozi',
#   'water',
#   'view',
#   'lodg',
#   'pool',
#   'sunset',
#   'view',
#   'clear',
#   'lake',
#   'everi',
#   'window',
#   'day',
#   'view',
#   'back',
#   'deck',
#   'overlook',
#   'bring',
#   'jet',
#   'use',
#   'ft',
#   'boat',
#   'love',
#   'place',
#   'high',
#   'ceil',
#   'great',
#   'solo',
#   'busi',
#   'famili',
#   'cozi',
#   'water',
#   'view'],
#  62: ['spare',
#   'room',
#   'within',
#   'bath',
#   'condo',
#   'within',
#   'medic',
#   'center',
#   'minut',
#   'away',
#   'hermann',
#   'rice',
#   'nrg',
#   'houston',
#   'medic',
#   'list',
#   'minut',
#   'walk',
#   'nearest',
#   'bus',
#   'stop',
#   'minut',
#   'walk',
#   'nearest',
#   'light',
#   'rail',
#   'toiletri',
#   'afford',
#   'med',
#   'center',
#   'room'],
#  63: ['fulli',
#   'remodel',
#   'furnish',
#   'home',
#   'central',
#   'locat',
#   'quiet',
#   'culdasec',
#   'station',
#   'home',
#   'boast',
#   'larg',
#   'live',
#   'spacious',
#   'kitchen',
#   'tile',
#   'counter',
#   'breakfast',
#   'area',
#   'eat',
#   'dine',
#   'room',
#   'open',
#   'kitchen',
#   'larg',
#   'enough',
#   'second',
#   'live',
#   'enjoy',
#   'even',
#   'back',
#   'porch',
#   'take',
#   'quick',
#   'walk',
#   'either',
#   'garden',
#   'acr',
#   'park',
#   'tanglewood',
#   'park',
#   'close',
#   'much',
#   'great',
#   'home',
#   'away',
#   'home'],
#  64: ['love',
#   'one',
#   'afford',
#   'medic',
#   'updat',
#   'furnish',
#   'bedroom',
#   'bathroom',
#   'condo',
#   'apart',
#   'modern',
#   'privat',
#   'bedroom',
#   'lock',
#   'bathroom',
#   'bedroom',
#   'suit',
#   'share',
#   'bedroom',
#   'anoth',
#   'kitchen',
#   'furnish',
#   'basic',
#   'cook',
#   'texa',
#   'medic',
#   'center',
#   'bedroom',
#   'bathroom',
#   'room'],
#  65: ['beauti',
#   'quiet',
#   'neighborhood',
#   'right',
#   'across',
#   'street',
#   'park',
#   'golf',
#   'privat',
#   'park',
#   'minut',
#   'away',
#   'nrg',
#   'perfect',
#   'place',
#   'relax',
#   'minut',
#   'away',
#   'ton',
#   'dine',
#   'take',
#   'home',
#   'right',
#   'golf',
#   'cours'],
#  66: ['make',
#   'home',
#   'doubl',
#   'size',
#   'bedroom',
#   'suit',
#   'privat',
#   'min',
#   'min',
#   'downtown',
#   'san',
#   'min',
#   'min',
#   'six',
#   'sea',
#   'famili',
#   'suit',
#   'privat',
#   'entranc'],
#  67: ['rent',
#   'entir',
#   'privat',
#   'guest',
#   'enjoy',
#   'outsid',
#   'pool',
#   'larg',
#   'along',
#   'saltwat',
#   'pool',
#   'heat',
#   'jacuzzi',
#   'enjoy',
#   'start',
#   'day',
#   'friend',
#   'enjoy',
#   'game',
#   'tenni',
#   'fill',
#   'one',
#   'mani',
#   'tourist',
#   'attract',
#   'healthi',
#   'lifestyl',
#   'privat',
#   'suit',
#   'poolsid',
#   'room'],
#  68: ['littl',
#   'blanco',
#   'gorgeous',
#   'vacat',
#   'rental',
#   'hous',
#   'locat',
#   'beauti',
#   'hole',
#   'golf',
#   'cours',
#   'also',
#   'one',
#   'highest',
#   'point',
#   'golf',
#   'livabl',
#   'space',
#   'bedroom',
#   'bathroom',
#   'sleep',
#   'singl',
#   'level',
#   'littl',
#   'blanco'],
#  69: ['bedroom',
#   'pictur',
#   'full',
#   'full',
#   'closet',
#   'chiffarob',
#   'chest',
#   'also',
#   'privat',
#   'access',
#   'tv',
#   'room',
#   'nice',
#   'famili',
#   'home',
#   'close',
#   'garland',
#   'mesquit'],
#  70: ['actual',
#   'treehousewelcom',
#   'spacious',
#   'bedroom',
#   'apart',
#   'locat',
#   'huge',
#   'work',
#   'lamin',
#   'hardwood',
#   'comfort',
#   'queen',
#   'size',
#   'bed',
#   'perk',
#   'great',
#   'space',
#   'offer',
#   'self',
#   'welcom',
#   'arriv',
#   'anytim',
#   'time',
#   'conveni',
#   'treehous',
#   'oasi',
#   'bike'],
#  71: ['place',
#   'close',
#   'bed',
#   'locat',
#   'front',
#   'room',
#   'close',
#   'rest',
#   'hous',
#   'peopl',
#   'love',
#   'place',
#   'neighborhood',
#   'place',
#   'good',
#   'solo',
#   'privat',
#   'room',
#   'locat',
#   'establish',
#   'neighborhood',
#   'quick',
#   'access',
#   'loop',
#   'us',
#   'minut',
#   'minut',
#   'perfect',
#   'anyon',
#   'visit',
#   'short',
#   'airport',
#   'trundl',
#   'bed',
#   'share',
#   'bath'],
#  72: ['wood',
#   'retreat',
#   'nestl',
#   'among',
#   'old',
#   'growth',
#   'oak',
#   'creek',
#   'five',
#   'minut',
#   'north',
#   'canyon',
#   'perfect',
#   'weekend',
#   'spot',
#   'get',
#   'back',
#   'import',
#   'scent',
#   'cedar',
#   'reinvigor',
#   'green',
#   'hill',
#   'crystal',
#   'clear',
#   'river',
#   'call',
#   'strateg',
#   'less',
#   'hour',
#   'away',
#   'fredericksburg',
#   'local',
#   'tax',
#   'emerald',
#   'gem',
#   'texa',
#   'hill',
#   'canyon',
#   'lake'],
#  73: ['place',
#   'close',
#   'austin',
#   'love',
#   'place',
#   'outdoor',
#   'comfi',
#   'place',
#   'good',
#   'solo',
#   'busi',
#   'shadow',
#   'glen'],
#  74: ['perfect',
#   'week',
#   'longer',
#   'master',
#   'privat',
#   'bath',
#   'other',
#   'share',
#   'deck',
#   'area',
#   'privat',
#   'feel',
#   'enjoy',
#   'smoke',
#   'fellowship',
#   'one',
#   'perfect',
#   'week',
#   'longer'],
#  75: ['top',
#   'floor',
#   'condominium',
#   'overlook',
#   'las',
#   'central',
#   'everyth',
#   'includ',
#   'major',
#   'groceri',
#   'fulli',
#   'privat',
#   'bedroom',
#   'everyth',
#   'might',
#   'need',
#   'privat',
#   'near',
#   'dfw',
#   'airport'],
#  76: ['delight',
#   'twin',
#   'design',
#   'privat',
#   'ensuit',
#   'pc',
#   'tv',
#   'person',
#   'beverag',
#   'center',
#   'stock',
#   'privat',
#   'addit',
#   'bed',
#   'avail',
#   'access',
#   'outdoor',
#   'space',
#   'pool',
#   'deckhom',
#   'histor',
#   'district',
#   'walk',
#   'distanc',
#   'downtown',
#   'squar',
#   'mckinney',
#   'known',
#   'vibrant',
#   'downtown',
#   'area',
#   'testament',
#   'money',
#   'magazin',
#   'rate',
#   'mckinney',
#   'place',
#   'beauti',
#   'victorian',
#   'farmhous'],
#  77: ['execut',
#   'furnish',
#   'apart',
#   'featur',
#   'bed',
#   'bath',
#   'spacious',
#   'famili',
#   'sleep',
#   'peopl',
#   'includ',
#   'fulli',
#   'equip',
#   'kitchen',
#   'modern',
#   'everyth',
#   'anybodi',
#   'would',
#   'need',
#   'cook',
#   'delici',
#   'pool',
#   'view',
#   'apart',
#   'also',
#   'featur',
#   'dramat',
#   'tile',
#   'custom',
#   'trim',
#   'crown',
#   'ceil',
#   'comput',
#   'desk',
#   'overs',
#   'garden',
#   'expans',
#   'closet',
#   'full',
#   'size',
#   'washer',
#   'gorgeous',
#   'pool',
#   'view'],
#  78: ['place',
#   'close',
#   'tamu',
#   'love',
#   'place',
#   'high',
#   'place',
#   'good',
#   'busi',
#   'famili',
#   'gameday',
#   'sleepov'],
#  79: ['hous',
#   'great',
#   'multipl',
#   'coupl',
#   'famili',
#   'cover',
#   'patio',
#   'patio',
#   'tabl',
#   'two',
#   'air',
#   'mattress',
#   'avail',
#   'locat',
#   'minut',
#   'downtown',
#   'hobbi',
#   'groceri',
#   'shop',
#   'center',
#   'within',
#   'walk',
#   'superbowl',
#   'home',
#   'rental'],
#  80: ['place',
#   'close',
#   'kyle',
#   'restaur',
#   'love',
#   'place',
#   'locat',
#   'outdoor',
#   'place',
#   'good',
#   'solo',
#   'busi',
#   'famili',
#   'big',
#   'furri',
#   'friend',
#   'bedroom',
#   'privat',
#   'room'],
#  81: ['list', 'femal', 'nice', 'semi', 'master', 'meadow', 'view'],
#  82: ['nice', 'home', 'modern', 'decor', 'north', 'fort', 'worth', 'home'],
#  83: ['euless',
#   'mile',
#   'dfw',
#   'airport',
#   'dalla',
#   'ft',
#   'close',
#   'attract',
#   'like',
#   'six',
#   'cowboy',
#   'ranger',
#   'stadium',
#   'also',
#   'near',
#   'american',
#   'airlin',
#   'train',
#   'pet',
#   'friend',
#   'home',
#   'charg',
#   'fee',
#   'per',
#   'week',
#   'per',
#   'pet',
#   'privat',
#   'room',
#   'near',
#   'airport'],
#  84: ['look',
#   'comfort',
#   'place',
#   'brentwood',
#   'charact',
#   'found',
#   'great',
#   'launch',
#   'pad',
#   'austin',
#   'adventur',
#   'locat',
#   'right',
#   'burnet',
#   'district',
#   'stone',
#   'throw',
#   'quick',
#   'public',
#   'transit',
#   'walk',
#   'sever',
#   'bar',
#   'includ',
#   'christma',
#   'yard',
#   'pour',
#   'aristocrat',
#   'sever',
#   'top',
#   'notch',
#   'bufalina',
#   'barley',
#   'austin',
#   'privat',
#   'patio',
#   'conveni',
#   'downtown',
#   'burnet'],
#  85: ['hous',
#   'tuck',
#   'away',
#   'end',
#   'quiet',
#   'minut',
#   'easi',
#   'drive',
#   'houston',
#   'intercontinent',
#   'easi',
#   'access',
#   'great',
#   'greenbelt',
#   'walk',
#   'busi',
#   'famili',
#   'two',
#   'kid',
#   'three',
#   'wonder',
#   'hous',
#   'hous',
#   'stay',
#   'privat',
#   'bedroom',
#   'full',
#   'bath',
#   'second',
#   'privat',
#   'bedroom',
#   'air',
#   'mattress',
#   'avail',
#   'larger',
#   'comfort',
#   'famili',
#   'home',
#   'near',
#   'iah'],
#  86: ['room',
#   'mountain',
#   'clear',
#   'wonder',
#   'neighborhood',
#   'minut',
#   'la',
#   'cantera',
#   'bathroom',
#   'game',
#   'room',
#   'make',
#   'feel',
#   'like',
#   'shampoo',
#   'provid',
#   'charm',
#   'room',
#   'minut',
#   'la'],
#  87: ['modern',
#   'townhous',
#   'las',
#   'mile',
#   'away',
#   'byron',
#   'nelson',
#   'golf',
#   'mile',
#   'away',
#   'dfw',
#   'home',
#   'perfect',
#   'larg',
#   'group',
#   'enjoy',
#   'open',
#   'floorplan',
#   'relax',
#   'back',
#   'cute',
#   'las',
#   'byron',
#   'nelson'],
#  88: ['room',
#   'heart',
#   'energi',
#   'la',
#   'kati',
#   'one',
#   'room',
#   'one',
#   'golf',
#   'full',
#   'close',
#   'park',
#   'toll',
#   'wayno',
#   'valid',
#   'driver',
#   'licens',
#   'due',
#   'book',
#   'room',
#   'heart'],
#  89: ['modern',
#   'luxuri',
#   'meet',
#   'charm',
#   'town',
#   'tctx',
#   'urban',
#   'lodg',
#   'await',
#   'minut',
#   'histor',
#   'lush',
#   'pool',
#   'secret',
#   'courtyard'],
#  90: ['fun',
#   'sun',
#   'repres',
#   'famili',
#   'great',
#   'experi',
#   'irreplac',
#   'experi',
#   'privat',
#   'boat',
#   'ramp',
#   'one',
#   'kind',
#   'hill',
#   'countri',
#   'refresh',
#   'water',
#   'seclud',
#   'locat',
#   'allow',
#   'float',
#   'swim',
#   'without',
#   'fun',
#   'sun',
#   'lake',
#   'hous'],
#  91: ['live',
#   'studi',
#   'full',
#   'half',
#   'master',
#   'bedroom',
#   'upstair',
#   'game',
#   'backyard',
#   'patio',
#   'locat',
#   'min',
#   'quiet',
#   'close',
#   'min',
#   'movi',
#   'etc',
#   'stori',
#   'home',
#   'bush',
#   'airport'],
#  92: ['fulli',
#   'furnish',
#   'studio',
#   'apart',
#   'privat',
#   'entranc',
#   'detach',
#   'includ',
#   'one',
#   'queen',
#   'size',
#   'bed',
#   'full',
#   'size',
#   'sofa',
#   'fulli',
#   'equip',
#   'cutleri',
#   'home',
#   'away',
#   'studio'],
#  93: ['oak',
#   'hav',
#   'lakesid',
#   'cottages',
#   'a',
#   'perfect',
#   'oak',
#   'hav',
#   'lakesid',
#   'cottages'],
#  94: ['place',
#   'good',
#   'solo',
#   'busi',
#   'famili',
#   'group',
#   'two',
#   'room',
#   'room',
#   'come',
#   'refriger',
#   'lgbt',
#   'cultur',
#   'religion',
#   'dfw',
#   'airport',
#   'cozi',
#   'room'],
#  95: ['place',
#   'close',
#   'texa',
#   'vet',
#   'love',
#   'place',
#   'dog',
#   'friend',
#   'place',
#   'great',
#   'student',
#   'research',
#   'visit',
#   'cosi',
#   'room',
#   'close',
#   'texa',
#   'vet',
#   'school'],
#  96: ['townhous',
#   'ride',
#   'nrg',
#   'medic',
#   'nightlif',
#   'offer',
#   'museum',
#   'hobbi',
#   'airport',
#   'short',
#   'cab',
#   'ride',
#   'perfect',
#   'situat',
#   'safe',
#   'communiti',
#   'offer',
#   'immedi',
#   'access',
#   'heart',
#   'via',
#   'freeway',
#   'enjoy',
#   'access',
#   'safe',
#   'high',
#   'secur',
#   'premium',
#   'separ',
#   'climat',
#   'control',
#   'individu',
#   'perfect',
#   'townhom',
#   'super',
#   'bowl',
#   'li',
#   'beyond'],
#  97: ['except',
#   'hous',
#   'provid',
#   'ultim',
#   'lakefront',
#   'getaway',
#   'next',
#   'texa',
#   'room',
#   'immens',
#   'home',
#   'terrif',
#   'locat',
#   'cedar',
#   'creek',
#   'outstand',
#   'home',
#   'water',
#   'eustac',
#   'lakefront',
#   'home'],
#  98: ['rent',
#   'beauti',
#   'home',
#   'built',
#   'new',
#   'section',
#   'hous',
#   'bedroom',
#   'one',
#   'half',
#   'stori',
#   'home',
#   'sq',
#   'ft',
#   'hous',
#   'corner',
#   'lot',
#   'locat',
#   'minut',
#   'drive',
#   'woodland',
#   'lake',
#   'pleas',
#   'let',
#   'know',
#   'thank',
#   'rent',
#   'built',
#   'corner'],
#  99: ['love',
#   'guest',
#   'suit',
#   'amen',
#   'queen',
#   'sleep',
#   'number',
#   'charm',
#   'suburban',
#   'escap'],
#  100: ['room',
#   'whether',
#   'travel',
#   'need',
#   'room',
#   'stay',
#   'look',
#   'weekend',
#   'short',
#   'stroll',
#   'countrysid',
#   'cedar',
#   'creek',
#   'room',
#   'lake'],
#  101: ['place',
#   'good',
#   'solo',
#   'busi',
#   'famili',
#   'big',
#   'furri',
#   'friend',
#   'home',
#   'away'],
#  102: ['hous',
#   'well',
#   'establish',
#   'neighborhood',
#   'mani',
#   'tree',
#   'wide',
#   'deer',
#   'seen',
#   'everi',
#   'day',
#   'often',
#   'close',
#   'river',
#   'love',
#   'place',
#   'open',
#   'famili',
#   'friend',
#   'place',
#   'good',
#   'solo',
#   'famili',
#   'hill'],
#  103: ['cozi',
#   'cabin',
#   'lake',
#   'mexia',
#   'nice',
#   'lake',
#   'fish',
#   'boat',
#   'launch',
#   'lux',
#   'queen',
#   'size',
#   'bed',
#   'comfi',
#   'couch',
#   'qualiti',
#   'sleep',
#   'perfect',
#   'get',
#   'away',
#   'spot',
#   'fish',
#   'peac',
#   'mile',
#   'waco',
#   'mile',
#   'nice',
#   'local',
#   'boutiqu',
#   'dine',
#   'excel',
#   'overs',
#   'bath',
#   'tub',
#   'book',
#   'stay',
#   'cozi',
#   'cabin',
#   'great',
#   'lake'],
#  104: ['locat',
#   'quiet',
#   'cute',
#   'comfi',
#   'room',
#   'sleep',
#   'kid',
#   'demand',
#   'car',
#   'servic',
#   'need',
#   'let',
#   'us',
#   'know',
#   'anyth',
#   'make',
#   'stay',
#   'room',
#   'pool'],
#  105: ['place',
#   'close',
#   'restaur',
#   'great',
#   'love',
#   'place',
#   'neighborhood',
#   'comfi',
#   'place',
#   'good',
#   'coupl',
#   'solo',
#   'earth',
#   'privat',
#   'room',
#   'common'],
#  106: ['stress',
#   'day',
#   'come',
#   'home',
#   'swim',
#   'privat',
#   'seclud',
#   'pool',
#   'soak',
#   'hot',
#   'multipl',
#   'outdoor',
#   'seat',
#   'area',
#   'allow',
#   'relax',
#   'unwind',
#   'sun',
#   'larg',
#   'light',
#   'cover',
#   'porch',
#   'ceil',
#   'fan',
#   'game',
#   'also',
#   'locat',
#   'near',
#   'hwi',
#   'min',
#   'dalla',
#   'min',
#   'locat',
#   'quiet',
#   'neighborhood',
#   'ton',
#   'close',
#   'quiet',
#   'bath',
#   'home',
#   'hot'],
#  107: ['creek',
#   'view',
#   'quarter',
#   'close',
#   'fiesta',
#   'sea',
#   'san',
#   'antonio',
#   'love',
#   'locat',
#   'beauti',
#   'part',
#   'texa',
#   'hill',
#   'countri',
#   'wonder',
#   'river',
#   'great',
#   'solo',
#   'busi',
#   'famili',
#   'rockin',
#   'b',
#   'ranch',
#   'creek',
#   'view',
#   'quarter'],
#  108: ['sweet',
#   'beauti',
#   'decor',
#   'effic',
#   'detach',
#   'garag',
#   'acr',
#   'landscap',
#   'complet',
#   'roko',
#   'queen',
#   'rain',
#   'galleria',
#   'mile',
#   'super',
#   'bowl',
#   'nrg',
#   'sweet'],
#  109: ['newli',
#   'renov',
#   'stay',
#   'comfort',
#   'fulli',
#   'furnish',
#   'bedroom',
#   'bath',
#   'perfect',
#   'locat',
#   'next',
#   'visit',
#   'apart',
#   'interior',
#   'complet',
#   'renov',
#   'top',
#   'bottom',
#   'hardwood',
#   'great',
#   'new',
#   'kitchen',
#   'granit',
#   'stainless',
#   'steel',
#   'applianc',
#   'beauti',
#   'bedroom',
#   'featur',
#   'queen',
#   'size',
#   'bed',
#   'crisp',
#   'clean',
#   'high',
#   'fluffi',
#   'towel',
#   'also',
#   'less',
#   'mile',
#   'bedroom',
#   'bath'],
#  110: ['privat',
#   'room',
#   'avail',
#   'townhom',
#   'eado',
#   'within',
#   'walk',
#   'distanc',
#   'new',
#   'rail',
#   'bike',
#   'trail',
#   'easi',
#   'access',
#   'medic',
#   'rice',
#   'rooftop',
#   'deck',
#   'gate',
#   'communiti',
#   'public',
#   'park',
#   'privat',
#   'modern',
#   'downtown'],
#  111: ['enjoy',
#   'newli',
#   'spacious',
#   'modern',
#   'back',
#   'home',
#   'right',
#   'hike',
#   'bike',
#   'quiet',
#   'peac',
#   'yet',
#   'less',
#   'mile',
#   'rainey',
#   'street',
#   'nightlif',
#   'downtown',
#   'garden',
#   'home',
#   'host',
#   'peac',
#   'seren',
#   'modern',
#   'urban',
#   'paradis'],
#  112: ['great', 'couch', 'sleep', 'comfort', 'couch', 'kati'],
#  113: ['lugar',
#   'aeropuert',
#   'encuentr',
#   'minut',
#   'centr',
#   'ciud',
#   'encuentr',
#   'centr',
#   'much',
#   'vid',
#   'nocturn',
#   'transport',
#   'public',
#   'minut',
#   'cas',
#   'autobus',
#   'van',
#   'centr',
#   'va',
#   'encant',
#   'lug',
#   'deb',
#   'cas',
#   'ambient',
#   'tech',
#   'aloj',
#   'buen',
#   'viajer',
#   'negoci',
#   'peaceful',
#   'hom',
#   'min',
#   'from',
#   'airport',
#   'min',
#   'downtown'],
#  114: ['safari',
#   'theme',
#   'master',
#   'bedroom',
#   'bath',
#   'locat',
#   'gate',
#   'communiti',
#   'lowest',
#   'greenvill',
#   'area',
#   'first',
#   'floor',
#   'room',
#   'accommod',
#   'peopl',
#   'full',
#   'length',
#   'ton',
#   'natur',
#   'privat',
#   'dual',
#   'jet',
#   'tub',
#   'larg',
#   'within',
#   'minut',
#   'leav',
#   'neighborhood',
#   'aliv',
#   'peopl',
#   'attend',
#   'superb',
#   'trader',
#   'groceri',
#   'special',
#   'food',
#   'privat',
#   'master',
#   'bedroom',
#   'trendi',
#   'lowest',
#   'greenvill'],
#  115: ['room',
#   'intent',
#   'design',
#   'relax',
#   'take',
#   'away',
#   'soft',
#   'tranquil',
#   'color',
#   'wall',
#   'make',
#   'feel',
#   'peac',
#   'calm',
#   'soft',
#   'white',
#   'pillow',
#   'simpl',
#   'eleg',
#   'décor',
#   'make',
#   'room',
#   'transport',
#   'pure',
#   'bliss',
#   'room',
#   'come',
#   'complet',
#   'queen',
#   'size',
#   'walk',
#   'seren',
#   'room'],
#  116: ['room',
#   'downstair',
#   'queen',
#   'bed',
#   'luxuri',
#   'larg',
#   'closet',
#   'ensuit',
#   'bathroom',
#   'spa',
#   'qualiti',
#   'towel',
#   'room',
#   'cabl',
#   'free',
#   'coffe',
#   'hair',
#   'mini',
#   'room',
#   'red',
#   'velvet',
#   'inn'],
#  117: ['beauti',
#   'hous',
#   'locat',
#   'minut',
#   'wellborn',
#   'road',
#   'give',
#   'straight',
#   'shot',
#   'kyle',
#   'hous',
#   'sleep',
#   'easili',
#   'accommod',
#   'will',
#   'sleep',
#   'perfect',
#   'place',
#   'texa',
#   'game',
#   'day',
#   'getaway',
#   'stadium'],
#  118: ['quaint',
#   'home',
#   'block',
#   'texa',
#   'three',
#   'one',
#   'share',
#   'wood',
#   'floor',
#   'throughout',
#   'bedroom',
#   'also',
#   'list',
#   'individu',
#   'need',
#   'one',
#   'gig',
#   'reveill',
#   'block',
#   'texa'],
#  119: ['unit',
#   'one',
#   'bedroom',
#   'one',
#   'bath',
#   'contemporari',
#   'condominium',
#   'full',
#   'din',
#   'live',
#   'perfect',
#   'famili',
#   'ocean',
#   'front',
#   'step',
#   'away',
#   'spectacular',
#   'view',
#   'bay',
#   'side',
#   'view',
#   'bound',
#   'fall',
#   'love',
#   'condo',
#   'condo',
#   'aquarius'],
#  120: ['warm',
#   'open',
#   'space',
#   'guesthous',
#   'cultur',
#   'medit',
#   'massag',
#   'studio',
#   'space',
#   'fill',
#   'natur',
#   'light',
#   'shiplap',
#   'ceil',
#   'offer',
#   'rest',
#   'view',
#   'onto',
#   'garden',
#   'gold',
#   'fish',
#   'small',
#   'toaster',
#   'towel',
#   'hair',
#   'dryer',
#   'bicycl',
#   'tour',
#   'north',
#   'oak',
#   'cliff',
#   'bishop',
#   'art',
#   'tub',
#   'yoga',
#   'massag',
#   'servic',
#   'oak',
#   'cliff',
#   'tini',
#   'hous'],
#  121: ['lugar',
#   'hobby',
#   'va',
#   'encant',
#   'espaci',
#   'extremely',
#   'aloj',
#   'buen',
#   'aventurer',
#   'famili',
#   'houston',
#   'min',
#   'nrg'],
#  122: ['lazi',
#   'breez',
#   'retreat',
#   'squar',
#   'newli',
#   'condo',
#   'north',
#   'padr',
#   'king',
#   'size',
#   'bed',
#   'pull',
#   'full',
#   'kitchen',
#   'dine',
#   'full',
#   'secur',
#   'walk',
#   'distanc',
#   'restaur',
#   'new',
#   'read',
#   'thing',
#   'close',
#   'king',
#   'bed'],
#  123: ['get',
#   'away',
#   'contrari',
#   'creek',
#   'seclud',
#   'two',
#   'stori',
#   'hous',
#   'lakesid',
#   'communiti',
#   'ten',
#   'minut',
#   'downtown',
#   'granburi',
#   'lakesid',
#   'surround',
#   'tree',
#   'creek',
#   'quiet',
#   'contrari',
#   'creek',
#   'cottag'],
#  124: ['studio',
#   'apart',
#   'locat',
#   'quiet',
#   'minut',
#   'drive',
#   'downtown',
#   'minut',
#   'drive',
#   'nrg',
#   'person',
#   'space',
#   'day',
#   'need',
#   'come',
#   'tv',
#   'coffe',
#   'oven',
#   'dish',
#   'lot',
#   'storag',
#   'apart',
#   'near',
#   'houston'],
#  125: ['maison',
#   'tranquill',
#   'littl',
#   'middl',
#   'pool',
#   'area',
#   'invit',
#   'host',
#   'friend',
#   'whether',
#   'come',
#   'san',
#   'antonio',
#   'work',
#   'feel',
#   'right',
#   'maison',
#   'tranquill'],
#  126: ['two',
#   'great',
#   'spacious',
#   'privat',
#   'bedroom',
#   'friend',
#   'home',
#   'great',
#   'famili',
#   'individu',
#   'explor',
#   'dalla',
#   'forth',
#   'worth',
#   'home',
#   'close',
#   'texa',
#   'six',
#   'flag',
#   'hurrican',
#   'dalla',
#   'forth',
#   'price',
#   'two',
#   'spacious',
#   'privat',
#   'bedroom',
#   'quiet'],
#  127: ['comfort',
#   'one',
#   'room',
#   'locat',
#   'first',
#   'floor',
#   'stori',
#   'metal',
#   'townhous',
#   'concret',
#   'garden',
#   'separ',
#   'close',
#   'cedar',
#   'restaur',
#   'major',
#   'tollway',
#   'bus',
#   'oaklawn',
#   'soft',
#   'contemporari',
#   'townhous'],
#  128: ['clean', 'min', 'walk', 'garag', 'includ', 'aloha', 'paradis'],
#  129: ['texa',
#   'cottag',
#   'great',
#   'mile',
#   'domain',
#   'whole',
#   'food',
#   'minut',
#   'downtown',
#   'mile',
#   'dell',
#   'corpor',
#   'round',
#   'rock',
#   'within',
#   'mile',
#   'dell',
#   'diamond',
#   'round',
#   'rock',
#   'express',
#   'easi',
#   'access',
#   'major',
#   'road',
#   'beelin',
#   'entir',
#   'home',
#   'bedroom',
#   'light',
#   'comfort',
#   'home',
#   'hospit',
#   'trail',
#   'love',
#   'rock',
#   'entir',
#   'home'],
#  130: ['recent',
#   'updat',
#   'locat',
#   'mile',
#   'phillip',
#   'cpchem',
#   'old',
#   'fire',
#   'pit',
#   'bbq',
#   'time',
#   'want',
#   'hous',
#   'locat',
#   'across',
#   'street',
#   'corner',
#   'store',
#   'store',
#   'gas',
#   'well',
#   'short',
#   'distanc',
#   'southbound',
#   'sever',
#   'restaur',
#   'deliv',
#   'artisan',
#   'inn'],
#  131: ['book',
#   'avail',
#   'aug',
#   'book',
#   'modern',
#   'privat',
#   'room',
#   'two',
#   'stori',
#   'locat',
#   'near',
#   'major',
#   'groceri',
#   'texa',
#   'star',
#   'golf',
#   'min',
#   'dfw',
#   'space',
#   'dalla',
#   'fort',
#   'great',
#   'travel',
#   'student',
#   'min',
#   'ut',
#   'busi',
#   'even',
#   'privat',
#   'room',
#   'gate',
#   'communiti',
#   'near',
#   'dfw',
#   'airport'],
#  132: ['quiet',
#   'apart',
#   'look',
#   'pool',
#   'attach',
#   'garag',
#   'privat',
#   'plano',
#   'delight'],
#  133: ['uniqu',
#   'style',
#   'tree',
#   'top',
#   'cabin',
#   'comfort',
#   'nest',
#   'cabin',
#   'piper',
#   'lane'],
#  134: ['bedroom',
#   'bathroom',
#   'custom',
#   'builder',
#   'prime',
#   'locat',
#   'hole',
#   'fairway',
#   'luxuri',
#   'tour',
#   'golf',
#   'golf',
#   'cours',
#   'advanc',
#   'tee',
#   'time',
#   'discount',
#   'avail',
#   'minut',
#   'georg',
#   'bush',
#   'iah',
#   'intern',
#   'mile',
#   'downtown',
#   'easi',
#   'access',
#   'eastex',
#   'mani',
#   'restaur',
#   'kroger',
#   'groceri',
#   'store',
#   'within',
#   'qti',
#   'bbq',
#   'back',
#   'yard',
#   'pet',
#   'kid',
#   'pet',
#   'fee',
#   'collect',
#   'separ',
#   'singl',
#   'stori',
#   'golf',
#   'cours',
#   'minut',
#   'iah'],
#  135: ['new',
#   'top',
#   'line',
#   'toy',
#   'hauler',
#   'minut',
#   'away',
#   'minut',
#   'away',
#   'highway',
#   'camper',
#   'oasi'],
#  136: ['home',
#   'love',
#   'view',
#   'access',
#   'perfect',
#   'place',
#   'solo',
#   'busi',
#   'furri',
#   'friend',
#   'enjoy',
#   'water',
#   'kayak',
#   'flat',
#   'adventur',
#   'beauti',
#   'lake',
#   'contact',
#   'host',
#   'lake',
#   'home',
#   'minut',
#   'frisco'],
#  137: ['full',
#   'room',
#   'light',
#   'antiqu',
#   'furnitur',
#   'dresser',
#   'hook',
#   'hang',
#   'cloth',
#   'doubl'],
#  138: ['enjoy',
#   'three',
#   'larg',
#   'bedroom',
#   'entir',
#   'hous',
#   'rent',
#   'sq',
#   'sleep',
#   'one',
#   'king',
#   'size',
#   'one',
#   'queen',
#   'one',
#   'doubl',
#   'day',
#   'bed',
#   'twin',
#   'full',
#   'near',
#   'air',
#   'forc',
#   'sea',
#   'world',
#   'six',
#   'flag',
#   'enjoy',
#   'beauti',
#   'live',
#   'pool',
#   'plenti',
#   'room',
#   'big',
#   'famili',
#   'fresh',
#   'towel',
#   'nearbi',
#   'groceri',
#   'fulli',
#   'furnish',
#   'safe',
#   'quiet',
#   'spacious',
#   'home',
#   'near',
#   'sea',
#   'world',
#   'lackland',
#   'afb'],
#  139: ['bungalow',
#   'recent',
#   'renov',
#   'modern',
#   'mile',
#   'walk',
#   'distanc',
#   'west',
#   'roger',
#   'cultur',
#   'safe',
#   'famili',
#   'friend',
#   'westsid',
#   'modern'],
#  140: ['room',
#   'pillow',
#   'top',
#   'mattress',
#   'curtain',
#   'block',
#   'light',
#   'get',
#   'peac',
#   'comfort',
#   'room',
#   'share',
#   'bathroom'],
#  141: ['place',
#   'close',
#   'veteran',
#   'park',
#   'post',
#   'oak',
#   'love',
#   'place',
#   'locat',
#   'peac',
#   'place',
#   'good',
#   'solo',
#   'busi',
#   'famili',
#   'cabin',
#   'wood'],
#  142: ['cozi',
#   'super',
#   'bowl',
#   'home',
#   'mile',
#   'secret',
#   'straight',
#   'shot',
#   'texa',
#   'stadium',
#   'medic',
#   'bath',
#   'set',
#   'peac',
#   'urban',
#   'neighborhood',
#   'right',
#   'border',
#   'kitchen',
#   'fulli',
#   'stock',
#   'even',
#   'ninja',
#   'enjoy',
#   'space',
#   'spread',
#   'super',
#   'close',
#   'upper',
#   'sugarland',
#   'freeway',
#   'need',
#   'locat',
#   'recommend',
#   'car',
#   'super',
#   'home',
#   'base'],
#  143: ['mile',
#   'downtown',
#   'san',
#   'antonio',
#   'mile',
#   'six',
#   'flag',
#   'mile',
#   'seaworld',
#   'mile',
#   'gruen',
#   'mile',
#   'san',
#   'marco',
#   'outlet',
#   'mile',
#   'austin',
#   'mile',
#   'canyon',
#   'mile',
#   'san',
#   'antonio',
#   'intern',
#   'airport',
#   'min',
#   'schlitterbaun',
#   'new',
#   'braunfel',
#   'wonder',
#   'home'],
#  144: ['famili',
#   'home',
#   'locat',
#   'outskirt',
#   'woodland',
#   'uniqu',
#   'conveni',
#   'experi',
#   'beauti',
#   'comfort',
#   'person',
#   'vacat',
#   'hous',
#   'may',
#   'look',
#   'small',
#   'mani',
#   'guest',
#   'feel',
#   'home',
#   'due',
#   'modern',
#   'modern',
#   'home',
#   'perfect',
#   'weekend',
#   'getaway',
#   'longer',
#   'work',
#   'relat',
#   'stay',
#   'modern',
#   'home',
#   'swim',
#   'pool',
#   'woodland'],
#  145: ['beauti',
#   'countri',
#   'retreat',
#   'locat',
#   'histor',
#   'independ',
#   'charm',
#   'superb',
#   'antiqu',
#   'fair',
#   'round',
#   'home',
#   'blue',
#   'bell',
#   'ice',
#   'bedroom',
#   'antiqu',
#   'fulli',
#   'self',
#   'contain',
#   'complet',
#   'kitchen',
#   'decor',
#   'antiqu',
#   'front',
#   'porch',
#   'rocker',
#   'enjoy',
#   'fresh',
#   'air',
#   'gorgeous',
#   'washington',
#   'brazo',
#   'state',
#   'park',
#   'close',
#   'minut',
#   'univers',
#   'perfect',
#   'littl',
#   'park',
#   'manor',
#   'guest'],
#  146: ['spacious',
#   'king',
#   'size',
#   'suit',
#   'satisfi',
#   'need',
#   'comfort',
#   'conveni',
#   'stay',
#   'san',
#   'min',
#   'min',
#   'fort',
#   'sam',
#   'min',
#   'downtown',
#   'san',
#   'min',
#   'airport',
#   'hr',
#   'militari',
#   'discountw',
#   'honor',
#   'serv',
#   'activ',
#   'reserv',
#   'militari',
#   'guest',
#   'fort',
#   'sam',
#   'houston',
#   'temporari',
#   'hous'],
#  147: ['beauti',
#   'stay',
#   'clean',
#   'remodel',
#   'quiet',
#   'safe',
#   'schertz',
#   'communiti',
#   'perfect',
#   'locat',
#   'close',
#   'nicest',
#   'place',
#   'san',
#   'antonio',
#   'offer',
#   'without',
#   'minut',
#   'san',
#   'antonio',
#   'minut',
#   'new',
#   'minut',
#   'san',
#   'antonio',
#   'river',
#   'minut',
#   'natur',
#   'bridg',
#   'cavernsgreat',
#   'famili',
#   'group',
#   'gorgeous',
#   'quiet',
#   'retreat'],
#  148: ['place',
#   'close',
#   'love',
#   'field',
#   'great',
#   'view',
#   'golf',
#   'cours',
#   'walk',
#   'enjoy',
#   'beauti',
#   'love',
#   'place',
#   'close',
#   'restaur',
#   'cultur',
#   'area',
#   'addison',
#   'minut',
#   'away',
#   'dallasmi',
#   'place',
#   'good',
#   'solo',
#   'busi',
#   'quiet',
#   'room',
#   'view'],
#  149: ['bluebonnet',
#   'cabin',
#   'place',
#   'natur',
#   'heal',
#   'cabin',
#   'perfect',
#   'acr',
#   'trail',
#   'greet',
#   'donkey',
#   'miniatur',
#   'oreo',
#   'funni',
#   'bantam',
#   'explor',
#   'cur',
#   'q',
#   'ranch',
#   'bluebonnet',
#   'cabin'],
#  150: ['welcom',
#   'full',
#   'bath',
#   'countri',
#   'getaway',
#   'best',
#   'place',
#   'relax',
#   'gather',
#   'around',
#   'fire',
#   'grill',
#   'master',
#   'grill',
#   'favorit',
#   'gas',
#   'enjoy',
#   'roast',
#   'sit',
#   'clearest',
#   'sky',
#   'home',
#   'offer',
#   'mani',
#   'outdoor',
#   'activ',
#   'includ',
#   'horseback',
#   'skeet',
#   'shoot',
#   'mud',
#   'locat',
#   'mile',
#   'waller',
#   'counti',
#   'fair',
#   'local',
#   'concert',
#   'countri',
#   'getaway',
#   'relax'],
#  151: ['complet',
#   'wisteria',
#   'bend',
#   'cottag',
#   'readi',
#   'guest',
#   'enjoy',
#   'two',
#   'bedroom',
#   'sunroom',
#   'queen',
#   'vintag',
#   'kitchen',
#   'live',
#   'pool',
#   'wbc',
#   'mile',
#   'lake',
#   'short',
#   'minut',
#   'heart',
#   'antiqu',
#   'festiv',
#   'warrenton',
#   'round',
#   'modern',
#   'conveni',
#   'includ',
#   'tvs',
#   'fulli',
#   'stock',
#   'piano',
#   'wisteria',
#   'bend',
#   'cottag'],
#  152: ['place',
#   'close',
#   'downtown',
#   'fort',
#   'west',
#   'cultur',
#   'district',
#   'comfi',
#   'tempurped',
#   'high',
#   'ceil',
#   'live',
#   'updat',
#   'room',
#   'great',
#   'solo',
#   'busi',
#   'privat',
#   'near',
#   'downtown',
#   'west'],
#  153: ['one',
#   'bedroom',
#   'condo',
#   'stun',
#   'view',
#   'lake',
#   'conro',
#   'walden',
#   'yacht',
#   'racquet',
#   'fit',
#   'center',
#   'within',
#   'walk',
#   'come',
#   'relax',
#   'beauti',
#   'lakefront',
#   'condo'],
#  154: ['model',
#   'ford',
#   'cargo',
#   'van',
#   'situat',
#   'larg',
#   'part',
#   'beauti',
#   'north',
#   'central',
#   'texa',
#   'three',
#   'pond',
#   'twelv',
#   'along',
#   'approxim',
#   'six',
#   'cabl',
#   'televis',
#   'run',
#   'water',
#   'van',
#   'river',
#   'classic',
#   'american',
#   'way',
#   'exist',
#   'offer',
#   'allow',
#   'opportun',
#   'see',
#   'world',
#   'viewpoint',
#   'nobl',
#   'vagabond',
#   'live',
#   'hidden',
#   'unseen',
#   'portion',
#   'real',
#   'river'],
#  155: ['place',
#   'close',
#   'great',
#   'citi',
#   'art',
#   'easi',
#   'access',
#   'stadium',
#   'super',
#   'bowl',
#   'love',
#   'place',
#   'high',
#   'place',
#   'good',
#   'solo',
#   'busi',
#   'famili',
#   'furri',
#   'friend',
#   'queen',
#   'queen',
#   'good',
#   'air',
#   'mattress',
#   'plenti',
#   'space',
#   'air',
#   'mattress',
#   'close',
#   'great',
#   'shop',
#   'super',
#   'bowl',
#   'weekend'],
#  156: ['place', 'wonder', 'worth', 'stay', 'place'],
#  157: ['place', 'close', 'art', 'restaur', 'place', 'good', 'pearl', 'cottag'],
#  158: ['locat',
#   'comal',
#   'river',
#   'heart',
#   'downtown',
#   'new',
#   'meet',
#   'tini',
#   'home',
#   'fill',
#   'charm',
#   'perfect',
#   'appropri',
#   'util',
#   'tini',
#   'sleep',
#   'tube',
#   'chute'],
#  159: ['one',
#   'bedroom',
#   'bed',
#   'breakfast',
#   'overlook',
#   'galveston',
#   'bay',
#   'room',
#   'includ',
#   'king',
#   'size',
#   'flat',
#   'screen',
#   'tv',
#   'privat',
#   'walk',
#   'distanc',
#   'kemah',
#   'shop',
#   'access',
#   'breakfast',
#   'captain',
#   'quarter',
#   'room'],
#  160: ['nest',
#   'privat',
#   'bedroom',
#   'guest',
#   'stay',
#   'locat',
#   'conveni',
#   'near',
#   'everi',
#   'major',
#   'highway',
#   'home',
#   'near',
#   'groceri',
#   'run',
#   'trail',
#   'minut',
#   'dfw',
#   'essenti',
#   'amazon',
#   'alexa'],
#  161: ['texa',
#   'starlight',
#   'ranch',
#   'sit',
#   'acr',
#   'land',
#   'also',
#   'natur',
#   'place',
#   'close',
#   'restaur',
#   'dine',
#   'love',
#   'place',
#   'ambianc',
#   'outdoor',
#   'place',
#   'good',
#   'solo',
#   'busi',
#   'famili',
#   'big',
#   'texa',
#   'starlight',
#   'ranch',
#   'also',
#   'great',
#   'holiday',
#   'parti',
#   'christma',
#   'new',
#   'texa',
#   'starlight',
#   'ranch'],
#  162: ['walk',
#   'enjoy',
#   'best',
#   'downtown',
#   'austin',
#   'offer',
#   'restaur',
#   'great',
#   'swanki',
#   'condo',
#   'perfect',
#   'locat',
#   'heart',
#   'provid',
#   'access',
#   'communiti',
#   'railyard',
#   'oasi',
#   'locat',
#   'downtown'],
#  163: ['spacious',
#   'open',
#   'concept',
#   'home',
#   'pine',
#   'floor',
#   'larg',
#   'vault',
#   'ceil',
#   'expos',
#   'wood',
#   'beam',
#   'wrap',
#   'around',
#   'porch',
#   'amaz',
#   'bedroom',
#   'bathroom',
#   'loft',
#   'sleep',
#   'area',
#   'spiral',
#   'top',
#   'line',
#   'granit',
#   'counter',
#   'larg',
#   'modern',
#   'bathroom',
#   'lot',
#   'slide',
#   'barn',
#   'door',
#   'much',
#   'noth',
#   'like',
#   'farm',
#   'hous'],
#  164: ['bedroom',
#   'w',
#   'full',
#   'bed',
#   'full',
#   'friend',
#   'dog',
#   'super',
#   'bowl',
#   'weekend'],
#  165: ['place',
#   'close',
#   'park',
#   'restaur',
#   'walk',
#   'groceri',
#   'coupl',
#   'restaur',
#   'love',
#   'place',
#   'privaci',
#   'easi',
#   'drive',
#   'downtown',
#   'chill',
#   'backyard',
#   'place',
#   'good',
#   'busi',
#   'famili',
#   'big',
#   'friend',
#   'cat',
#   'hondo',
#   'basic',
#   'ignor',
#   'allerg',
#   'may',
#   'best',
#   'home',
#   'br',
#   'home',
#   'minut',
#   'downtown',
#   'hill',
#   'countri'],
#  167: ['casita',
#   'creek',
#   'littl',
#   'cottag',
#   'locat',
#   'minut',
#   'main',
#   'rent',
#   'angel',
#   'haus',
#   'casita',
#   'creek',
#   'guest',
#   'separ',
#   'door',
#   'unlock',
#   'provid',
#   'seamless',
#   'casita',
#   'creek'],
#  168: ['newli',
#   'built',
#   'home',
#   'modern',
#   'larg',
#   'open',
#   'floor',
#   'car',
#   'garag',
#   'park',
#   'spacious',
#   'full',
#   'bath',
#   'half',
#   'bedroom',
#   'accommod',
#   'everyon',
#   'separ',
#   'sit',
#   'relax',
#   'room'],
#  169: ['howdi',
#   'direct',
#   'list',
#   'locat',
#   'section',
#   'amaz',
#   'guest',
#   'use',
#   'instant',
#   'room',
#   'amaz',
#   'quiet',
#   'oasi',
#   'south',
#   'austin',
#   'wonder',
#   'music',
#   'incred',
#   'sight',
#   'see',
#   'enjoy',
#   'privat',
#   'bedroom',
#   'inch',
#   'foam',
#   'queen',
#   'size',
#   'mattress',
#   'four',
#   'post',
#   'closet',
#   'locat',
#   'quiet',
#   'south',
#   'austin',
#   'neighborhood',
#   'includ',
#   'continent',
#   'appl',
#   'tv',
#   'wireless',
#   'internet',
#   'lazi',
#   'retreat'],
#  170: ['separ',
#   'entranc',
#   'studio',
#   'full',
#   'second',
#   'floor',
#   'countri',
#   'hous',
#   'situat',
#   'acr',
#   'bluebonnet',
#   'countri',
#   'houston',
#   'complet',
# ...
#   'home',
#   'get',
#   'awar',
#   'live',
#   'parkview',
#   'two',
#   'bed',
#   'room'],
#  958: ['sq',
#   'foot',
#   'cabin',
#   'built',
#   'open',
#   'kitchen',
#   'area',
#   'equip',
#   'boardliv',
#   'room',
#   'downstair',
#   'sand',
#   'cover',
#   'parkingno',
#   'pet',
#   'satellit',
#   'cabana'],
#  959: ['list',
#   'close',
#   'art',
#   'northpark',
#   'mall',
#   'downtown',
#   'love',
#   'list',
#   'comfi',
#   'high',
#   'place',
#   'good',
#   'solo',
#   'busi',
#   'coffe',
#   'milk',
#   'provid',
#   'commit',
#   'cleanli',
#   'chang',
#   'clean',
#   'list',
#   'feel',
#   'like',
#   'bedroom',
#   'kitchen'],
#  960: ['furnish',
#   'bed',
#   'bath',
#   'cozi',
#   'condo',
#   'sleep',
#   'dog',
#   'okal',
#   'tile',
#   'marbl',
#   'floor',
#   'bathroomqueen',
#   'bed',
#   'plus',
#   'futon',
#   'sofa',
#   'bed',
#   'live',
#   'room',
#   'equip',
#   'kitchen',
#   'marbl',
#   'bathroom',
#   'tile',
#   'floor',
#   'outdoor',
#   'walk',
#   'glass',
#   'patio',
#   'balconyflat',
#   'screen',
#   'tv',
#   'roku',
#   'internet',
#   'modem',
#   'router',
#   'tile',
#   'front',
#   'loader',
#   'washer',
#   'dryerwalk',
#   'closetreserv',
#   'cover',
#   'parkingg',
#   'communiti',
#   'pool',
#   'hot',
#   'tub',
#   'furnish',
#   'condo',
#   'north',
#   'dalla',
#   'sleep',
#   'pet',
#   'ok'],
#  961: ['beachview',
#   'bath',
#   'larg',
#   'open',
#   'space',
#   'live',
#   'din',
#   'kitchen',
#   'wet',
#   'locat',
#   'stori',
#   'front',
#   'tenni',
#   'court',
#   'swim',
#   'easi',
#   'access',
#   'close',
#   'walk',
#   'distanc',
#   'mani',
#   'restaur',
#   'south',
#   'padr',
#   'island',
#   'beachview',
#   'condominium'],
#  962: ['yellow',
#   'room',
#   'furnish',
#   'most',
#   'antiqu',
#   'furnitur',
#   'earli',
#   'late',
#   'bed',
#   'queen',
#   'size',
#   'face',
#   'gold',
#   'frame',
#   'flat',
#   'screen',
#   'tv',
#   'numer',
#   'curio',
#   'adorn',
#   'shelv',
#   'like',
#   'small',
#   'collect',
#   'strang',
#   'look',
#   'iron',
#   'book',
#   'hundr',
#   'year',
#   'also',
#   'current',
#   'book',
#   'well',
#   'stock',
#   'larg',
#   'bathroom',
#   'offer',
#   'whirlpool',
#   'tub',
#   'addit',
#   'larg',
#   'coffe',
#   'machin',
#   'provid',
#   'along',
#   'various',
#   'coffe',
#   'help',
#   'stay',
#   'awak',
#   'plan',
#   'watch',
#   'tv',
#   'small',
#   'refriger',
#   'provid',
#   'stock',
#   'soda',
#   'bottl',
#   'window',
#   'compliment',
#   'sheer',
#   'curtain',
#   'look',
#   'garden',
#   'good',
#   'premis',
#   'elect',
#   'watch',
#   'movi',
#   'movi',
#   'exercis',
#   'game',
#   'room',
#   'go',
#   'fish',
#   'well',
#   'stock',
#   'free',
#   'park',
#   'avail',
#   'along',
#   'swim',
#   'pool',
#   'soak',
#   'hot',
#   'come',
#   'stay',
#   'night',
#   'us',
#   'enjoy',
#   'scrumptious',
#   'breakfast',
#   'even',
#   'espresso',
#   'yellow',
#   'room',
#   'book',
#   'nook',
#   'inn'],
#  963: ['easi',
#   'walk',
#   'distanc',
#   'beach',
#   'view',
#   'gulf',
#   'close',
#   'restaur',
#   'granit',
#   'stainless',
#   'bamboo',
#   'floor',
#   'lot',
#   'beach',
#   'garag',
#   'hous',
#   'bbq',
#   'beach',
#   'washer',
#   'board',
#   'ador',
#   'beachsid',
#   'cottag'],
#  964: ['third',
#   'floor',
#   'condo',
#   'great',
#   'balconi',
#   'view',
#   'comal',
#   'river',
#   'landa',
#   'park',
#   'golf',
#   'august',
#   'instal',
#   'privat',
#   'slow',
#   'internet',
#   'share',
#   'rest',
#   'right',
#   'river',
#   'properti',
#   'enjoy',
#   'one',
#   'longest',
#   'float',
#   'river',
#   'tube',
#   'air',
#   'pump',
#   'downtown',
#   'includ',
#   'wurstfest',
#   'walk',
#   'pool',
#   'hot',
#   'tub',
#   'central',
#   'everyth'],
#  965: ['perfect',
#   'getaway',
#   'closest',
#   'vacat',
#   'rental',
#   'within',
#   'walk',
#   'distanc',
#   'world',
#   'famous',
#   'market',
#   'fenc',
#   'yard',
#   'surround',
#   'beauti',
#   'oak',
#   'kick',
#   'back',
#   'countri',
#   'townhom'],
#  966: ['spacious',
#   'apart',
#   'fulli',
#   'furnish',
#   'everyth',
#   'need',
#   'comfort',
#   'locat',
#   'apart',
#   'within',
#   'step',
#   'path',
#   'buffalo',
#   'bayou',
#   'minut',
#   'midtown',
#   'modern',
#   'apt',
#   'montros',
#   'cubbi',
#   'balconi'],
#  967: ['perfect',
#   'super',
#   'bowl',
#   'free',
#   'chauffeur',
#   'super',
#   'bowl',
#   'club',
#   'houston',
#   'driver',
#   'servic',
#   'whole',
#   'super',
#   'bowl',
#   'tamarron',
#   'tx'],
#  968: ['place',
#   'close',
#   'restaur',
#   'retail',
#   'store',
#   'target',
#   'walmart',
#   'close',
#   'highway',
#   'srt',
#   'provid',
#   'quick',
#   'access',
#   'love',
#   'spacious',
#   'clean',
#   'second',
#   'floor',
#   'entir',
#   'ensur',
#   'near',
#   'full',
#   'space',
#   'need',
#   'bedroom',
#   'pleas',
#   'sure',
#   'work',
#   'place',
#   'good',
#   'solo',
#   'busi',
#   'famili',
#   'big',
#   'gorgeous',
#   'spacious',
#   'home',
#   'privat',
#   'bedroom'],
#  969: ['basic',
#   'two',
#   'level',
#   'cabin',
#   'privat',
#   'ranch',
#   'twin',
#   'room',
#   'second',
#   'level',
#   'sleep',
#   'creekwood',
#   'cabin'],
#  970: ['quiet',
#   'place',
#   'southwest',
#   'surround',
#   'excel',
#   'restaur',
#   'minut',
#   'south',
#   'congress',
#   'perfect',
#   'place',
#   'big',
#   'grassi',
#   'area',
#   'mile',
#   'walk',
#   'trail',
#   'right',
#   'behind',
#   'pool',
#   'area',
#   'alway',
#   'clean',
#   'insid',
#   'clean',
#   'comfort',
#   'great',
#   'natur',
#   'live',
#   'room',
#   'cozi',
#   'free',
#   'wifi',
#   'access',
#   'xbox',
#   'love',
#   'stay',
#   'privat',
#   'condo',
#   'southwest',
#   'austin'],
#  971: ['home',
#   'rustic',
#   'mexican',
#   'style',
#   'casual',
#   'locat',
#   'foot',
#   'relax',
#   'home',
#   'bar',
#   'pool',
#   'tabl'],
#  972: ['place',
#   'close',
#   'sport',
#   'cowboy',
#   'restaur',
#   'central',
#   'locat',
#   'minut',
#   'dalla',
#   'love',
#   'home',
#   'beauti',
#   'walk',
#   'weekend',
#   'old',
#   'western',
#   'style',
#   'bank',
#   'robberi',
#   'hold',
#   'railroad',
#   'track',
#   'locat',
#   'minut',
#   'great',
#   'space',
#   'famili',
#   'reunion',
#   'relax',
#   'hous',
#   'patio',
#   'spectacular',
#   'outdoor',
#   'kitchen',
#   'area',
#   'larg',
#   'waterfal',
#   'famili',
#   'resort'],
#  973: ['locat',
#   'conveni',
#   'everyth',
#   'woodland',
#   'includ',
#   'woodland',
#   'bedroom',
#   'street',
#   'kitchen',
#   'park',
#   'bike',
#   'walk',
#   'trail',
#   'also',
#   'two',
#   'dog',
#   'love',
#   'snuggl',
#   'boho',
#   'chic',
#   'bedroom'],
#  974: ['properti',
#   'rambl',
#   'duplex',
#   'conveni',
#   'locat',
#   'less',
#   'one',
#   'hour',
#   'austin',
#   'less',
#   'two',
#   'hour',
#   'houston',
#   'san',
#   'largest',
#   'two',
#   'rental',
#   'offer',
#   'visitor',
#   'ampl',
#   'privaci',
#   'sole',
#   'use',
#   'pool',
#   'owner',
#   'occupi',
#   'smaller',
#   'second',
#   'though',
#   'new',
#   'rmr',
#   'success',
#   'rental',
#   'sinc',
#   'properti',
#   'visit',
#   'real',
#   'seclud',
#   'home',
#   'acr'],
#  975: ['larg',
#   'bedroom',
#   'privat',
#   'privat',
#   'bath',
#   'beauti',
#   'pool',
#   'overlook',
#   'gorgeous',
#   'hill',
#   'countri',
#   'coffeemak',
#   'internet',
#   'room',
#   'cloth',
#   'option',
#   'resort',
#   'style',
#   'properti',
#   'stun',
#   'hill',
#   'countri',
#   'estat'],
#  976: ['villa',
#   'bath',
#   'villa',
#   'bill',
#   'perfect',
#   'place',
#   'one',
#   'two',
#   'queen',
#   'size',
#   'larg',
#   'small',
#   'hot',
#   'toaster',
#   'huge',
#   'tile',
#   'free',
#   'direct',
#   'host',
#   'live',
#   'tri',
#   'welcom',
#   'also',
#   'respect',
#   'privaci',
#   'never',
#   'either',
#   'space',
#   'enjoy',
#   'uniqu',
#   'upscal',
#   'extend',
#   'stay',
#   'villa',
#   'apart'],
#  977: ['inquir',
#   'mayb',
#   'clean',
#   'fee',
#   'book',
#   'request',
#   'day',
#   'king',
#   'two',
#   'full',
#   'bed',
#   'second',
#   'king',
#   'third',
#   'sleeper',
#   'sofa',
#   'live',
#   'maximum',
#   'occup',
#   'season',
#   'rate',
#   'higher',
#   'what',
#   'list',
#   'current',
#   'rate',
#   'calendar',
#   'valid',
#   'book',
#   'request',
#   'within',
#   'day',
#   'marbl',
#   'fall'],
#  978: ['memori',
#   'holiday',
#   'almost',
#   'upon',
#   'wonder',
#   'san',
#   'texa',
#   'blue',
#   'bell',
#   'stucco',
#   'two',
#   'stori',
#   'home',
#   'quiet',
#   'summerwood',
#   'privat',
#   'spectacular',
#   'locat',
#   'right',
#   'next',
#   'door',
#   'nation',
#   'recogn',
#   'medic',
#   'center',
#   'san',
#   'look',
#   'forward',
#   'texa',
#   'blue',
#   'bell',
#   'medic',
#   'center'],
#  979: ['villag',
#   'beach',
#   'first',
#   'class',
#   'live',
#   'texa',
#   'gulf',
#   'coast',
#   'come',
#   'stay',
#   'enjoy',
#   'one',
#   'luxuri',
#   'villag',
#   'beach',
#   'rental',
#   'villag',
#   'beach'],
#  980: ['place',
#   'good',
#   'solo',
#   'busi',
#   'travel',
#   'also',
#   'close',
#   'min',
#   'drivesix',
#   'flag',
#   'amus',
#   'min',
#   'drivesix',
#   'flag',
#   'hurrican',
#   'harbor',
#   'min',
#   'drivedfw',
#   'min',
#   'drive',
#   'cozi',
#   'comfi',
#   'apt',
#   'close',
#   'everywher',
#   'free',
#   'park'],
#  981: ['perfect',
#   'bed',
#   'bath',
#   'top',
#   'lake',
#   'best',
#   'mall',
#   'dalla',
#   'north',
#   'memori',
#   'foam',
#   'bed',
#   'larg',
#   'well',
#   'appoint',
#   'search',
#   'found',
#   'perfect',
#   'luxuri',
#   'holiday',
#   'home',
#   'dalla'],
#  982: ['hidden',
#   'util',
#   'clean',
#   'bath',
#   'town',
#   'home',
#   'master',
#   'reserv',
#   'park',
#   'spot',
#   'resort',
#   'pool',
#   'picnic',
#   'tabl',
#   'play',
#   'close',
#   'beach',
#   'nation',
#   'corpus',
#   'port',
#   'aransa',
#   'short',
#   'drive',
#   'concert',
#   'award',
#   'win',
#   'aa',
#   'horseback',
#   'ride',
#   'gull',
#   'cottag',
#   'mile',
#   'beach',
#   'localtax',
#   'includ'],
#  983: ['furnitur',
#   'bedroom',
#   'purchas',
#   'oct',
#   'bed',
#   'sheet',
#   'wash',
#   'new',
#   'guest',
#   'clean',
#   'towel',
#   'provid',
#   'bathroom',
#   'frequent',
#   'dfw',
#   'airport',
#   'love',
#   'field',
#   'airport',
#   'larg',
#   'tabl',
#   'separ',
#   'room',
#   'din',
#   'jack',
#   'jill',
#   'high',
#   'speed',
#   'wifi',
#   'free',
#   'coffe',
#   'home',
#   'safe',
#   'neighborhood',
#   'secur',
#   'system',
#   'simmon',
#   'beautyrest',
#   'king',
#   'bed'],
#  984: ['lake',
#   'enjoy',
#   'point',
#   'ventur',
#   'silverton',
#   'custom',
#   'home',
#   'built',
#   'plenti',
#   'enjoy',
#   'clear',
#   'blue',
#   'water',
#   'lake',
#   'travi',
#   'pv',
#   'pv',
#   'golf',
#   'cours',
#   'tenni',
#   'one',
#   'six',
#   'kamp',
#   'king',
#   'lakeview',
#   'lake',
#   'travi'],
#  985: ['place',
#   'close',
#   'public',
#   'moon',
#   'tower',
#   'strang',
#   'farmer',
#   'market',
#   'love',
#   'place',
#   'comfi',
#   'bed',
#   'organ',
#   'cotton',
#   'outdoor',
#   'non',
#   'toxic',
#   'indoor',
#   'place',
#   'good',
#   'solo',
#   'adventur',
#   'busi',
#   'red',
#   'room'],
#  986: ['import',
#   'know',
#   'book',
#   'list',
#   'privat',
#   'quiet',
#   'pad',
#   'site',
#   'park',
#   'rv',
#   'camper',
#   'connect',
#   'amp',
#   'access',
#   'main',
#   'mile',
#   'denton',
#   'downtown',
#   'nearbi',
#   'love',
#   'public',
#   'close',
#   'apoge',
#   'interst',
#   'privat',
#   'rv',
#   'camper',
#   'site',
#   'near',
#   'downtown',
#   'denton'],
#  987: ['guest',
#   'room',
#   'closet',
#   'privat',
#   'piec',
#   'full',
#   'larg',
#   'quit',
#   'street',
#   'minut',
#   'minut',
#   'austin',
#   'live',
#   'one',
#   'room',
#   'privat',
#   'bathroom'],
#  988: ['stori',
#   'cozi',
#   'home',
#   'nestl',
#   'upscal',
#   'neighborhood',
#   'walk',
#   'distanc',
#   'olympia',
#   'golf',
#   'univers',
#   'citi',
#   'minut',
#   'san',
#   'antonio',
#   'intern',
#   'gateway',
#   'randolph',
#   'air',
#   'forc',
#   'minut',
#   'retama',
#   'park',
#   'hors',
#   'race',
#   'randolph',
#   'aviat',
#   'pit',
#   'pad'],
#  989: ['brand',
#   'new',
#   'fulli',
#   'furnish',
#   'home',
#   'locat',
#   'minut',
#   'spacious',
#   'bedroom',
#   'sleep',
#   'larg',
#   'open',
#   'live',
#   'room',
#   'outsid',
#   'deck',
#   'gas',
#   'keger',
#   'also',
#   'mile',
#   'formula',
#   'track'],
#  990: ['place',
#   'close',
#   'texa',
#   'ranger',
#   'dfw',
#   'love',
#   'field',
#   'highland',
#   'shop',
#   'love',
#   'place',
#   'situat',
#   'dalla',
#   'ft',
#   'clean',
#   'place',
#   'good',
#   'solo',
#   'busi',
#   'arlington',
#   'apart',
#   'near',
#   'cowboy',
#   'stadium'],
#  991: ['afford',
#   'condo',
#   'short',
#   'walk',
#   'great',
#   'bar',
#   'mass',
#   'convent',
#   'music',
#   'hike',
#   'bike',
#   'major',
#   'downtown',
#   'perfect',
#   'busi',
#   'travel',
#   'leisur',
#   'visit',
#   'see',
#   'full',
#   'descript',
#   'concierg',
#   'servic',
#   'perfect'],
#  992: ['cozi', 'clean', 'space', 'beauti', 'set', 'seren', 'place', 'iii'],
#  993: ['cabin',
#   'surround',
#   'wood',
#   'face',
#   'acr',
#   'woodland',
#   'perfect',
#   'everi',
#   'cabin',
#   'offer',
#   'luxuri',
#   'seren',
#   'surround',
#   'oreo',
#   'boy',
#   'wonder',
#   'lili',
#   'pond',
#   'natur'],
#  994: ['minut',
#   'fort',
#   'worth',
#   'cultur',
#   'fine',
#   'casual',
#   'hike',
#   'trail',
#   'friend',
#   'walk',
#   'bike',
#   'laser',
#   'cultur',
#   'stock',
#   'museum',
#   'much',
#   'nightlif',
#   'finest',
#   'piano',
#   'music',
#   'hall',
#   'danc',
#   'billi',
#   'southern',
#   'comfort'],
#  995: ['made',
#   'home',
#   'special',
#   'creat',
#   'beauti',
#   'sanctuari',
#   'decor',
#   'open',
#   'concept',
#   'kitchen',
#   'fulli',
#   'equip',
#   'anyth',
#   'would',
#   'need',
#   'creat',
#   'beauti',
#   'dinner',
#   'signific',
#   'room',
#   'extrem',
#   'larg',
#   'provid',
#   'toiletri',
#   'bathroom',
#   'bowl',
#   'bed',
#   'larg',
#   'backyard',
#   'grill',
#   'famili',
#   'love',
#   'beauti',
#   'quiet',
#   'pflugervill',
#   'home'],
#  996: ['upstair',
#   'suit',
#   'includ',
#   'huge',
#   'bedroom',
#   'famili',
#   'room',
#   'marina',
#   'view',
#   'locat',
#   'close',
#   'kemah',
#   'boardwalk',
#   'famili',
#   'comfort',
#   'bedroom',
#   'bath',
#   'minut',
#   'kemah',
#   'minut',
#   'nrg',
#   'stadium',
#   'superbowl',
#   'easi',
#   'access',
#   'galveston',
#   'nasa',
#   'space',
#   'center',
#   'featur',
#   'holiday'],
#  997: ['home',
#   'avail',
#   'entir',
#   'home',
#   'conduc',
#   'schedul',
#   'partial',
#   'room',
#   'rental',
#   'care',
#   'profession',
#   'close',
#   'va',
#   'want',
#   'move',
#   'home',
#   'leas',
#   'year',
#   'rate',
#   'room',
#   'also',
#   'ok',
#   'privat',
#   'bedroom'],
#  998: ['everi',
#   'corner',
#   'austin',
#   'within',
#   'easi',
#   'place',
#   'great',
#   'peopl',
#   'move',
#   'town',
#   'want',
#   'get',
#   'feel',
#   'rent',
#   'total',
#   'quiet',
#   'land',
#   'pad',
#   'new',
#   'arriv'],
#  999: ['give',
#   'discount',
#   'previous',
#   'guest',
#   'present',
#   'peac',
#   'home',
#   'gorgeous',
#   'view',
#   'relax',
#   'chill',
#   'scenic',
#   'wait',
#   'host',
#   'meet',
#   'one',
#   'block',
#   'away',
#   'metro',
#   'ride',
#   'main',
#   'walk',
#   'distanc',
#   'mani',
#   'shop',
#   'toyota',
#   'discoveri',
#   'downtown',
#   'hi',
#   'rise',
#   'amaz',
#   'view'],
#  1000: ['charm',
#   'condo',
#   'avail',
#   'center',
#   'downtown',
#   'worri',
#   'downtown',
#   'dedic',
#   'park',
#   'spot',
#   'extrem',
#   'conveni',
#   'locat',
#   'across',
#   'street',
#   'convent',
#   'center',
#   'block',
#   'away',
#   'train',
#   'sever',
#   'bus',
#   'within',
#   'walk',
#   'distanc',
#   'best',
#   'austin',
#   'offer',
#   'includ',
#   'rainey',
#   'south',
#   'sever',
#   'hike',
#   'trail',
#   'truli',
#   'someth',
#   'beauti',
#   'apt',
#   'middl',
#   'downtown'],
#  1001: ['luxuri',
#   'cabin',
#   'reserv',
#   'lake',
#   'contemporari',
#   'style',
#   'interior',
#   'classic',
#   'lakefront',
#   'dip',
#   'float',
#   'lazi',
#   'dock',
#   'boat',
#   'privat',
#   'reserv',
#   'lake',
#   'travi',
#   'cabin'],
#  1002: ['get',
#   'everywher',
#   'cultur',
#   'medic',
#   'west',
#   'comfi',
#   'guest',
#   'hous',
#   'close'],
#  1003: ['make',
#   'home',
#   'lakehous',
#   'safe',
#   'establish',
#   'neighborhood',
#   'overlook',
#   'beauti',
#   'lake',
#   'belton',
#   'conveni',
#   'minut',
#   'mh',
#   'expo',
#   'minut',
#   'templ',
#   'mile',
#   'east',
#   'ft',
#   'comfi',
#   'room',
#   'new',
#   'queen',
#   'bed',
#   'updat',
#   'master',
#   'coffe',
#   'tea',
#   'morn',
#   'light',
#   'kitchen',
#   'lake',
#   'retreat'],
#  1004: ['perfect',
#   'space',
#   'famili',
#   'friend',
#   'travel',
#   'togeth',
#   'want',
#   'stay',
#   'tudor',
#   'execut',
#   'home'],
#  1005: ['two',
#   'bedroom',
#   'apart',
#   'heart',
#   'templ',
#   'perfect',
#   'place',
#   'away',
#   'home',
#   'locat',
#   'scott',
#   'white',
#   'hospit',
#   'templ',
#   'mall',
#   'walmart',
#   'stone',
#   'throw',
#   'austin',
#   'fort',
#   'hood',
#   'respect',
#   'home',
#   'away',
#   'home'],
#  1006: ['best',
#   'one',
#   'person',
#   'two',
#   'peopl',
#   'sleep',
#   'separ',
#   'bed',
#   'fun',
#   'antiqu',
#   'store',
#   'close',
#   'well',
#   'good',
#   'walkabl',
#   'johnson',
#   'space',
#   'center',
#   'space',
#   'center',
#   'houston',
#   'center',
#   'minut',
#   'either',
#   'way',
#   'around',
#   'clear',
#   'freedom',
#   'sailboat'],
#  1007: ['look',
#   'perfect',
#   'stay',
#   'houston',
#   'click',
#   'modern',
#   'one',
#   'bedroom',
#   'brand',
#   'new',
#   'talk',
#   'locat',
#   'galleria',
#   'easi',
#   'access',
#   'tv',
#   'live',
#   'comfort',
#   'washer',
#   'dryer',
#   'look',
#   'luxuri'],
#  ...}

# %%
voc = {}
cont = 0
for key, value in docdict.items():
    for elem in value:
        if(elem not in voc):
            voc[elem] = cont
            cont += 1
print(voc)
# Out:
# {'welcom': 0, 'stay': 1, 'privat': 2, 'room': 3, 'queen': 4, 'bed': 5, 'detach': 6, 'bathroom': 7, 'second': 8, 'anoth': 9, 'bedroom': 10, 'sofa': 11, 'avail': 12, 'addit': 13, 'iah': 14, 'airportairport': 15, 'airport': 16, 'fulli': 17, 'remodel': 18, 'home': 19, 'upscal': 20, 'nw': 21, 'alamo': 22, 'height': 23, 'amaz': 24, 'locat': 25, 'hous': 26, 'conveni': 27, 'quiet': 28, 'beauti': 29, 'season': 30, 'prestigi': 31, 'neighborhood': 32, 'close': 33, 'loop': 34, 'featur': 35, 'open': 36, 'floor': 37, 'origin': 38, 'hardwood': 39, 'full': 40, 'independ': 41, 'sleep': 42, 'moreeuropean': 43, 'inspir': 44, 'kitchen': 45, 'driveway': 46, 'park': 47, 'uniqu': 48, 'design': 49, 'island': 50, 'well': 51, 'maintain': 52, 'river': 53, 'san': 54, 'jacinto': 55, 'extra': 56, 'temporari': 57, 'near': 58, 'citi': 59, 'cute': 60, 'littl': 61, 'situat': 62, 'covet': 63, 'garden': 64, 'acr': 65, 'access': 66, 'campus': 67, 'recent': 68, 'purchas': 69, 'mile': 70, 'outsid': 71, 'downtown': 72, 'fort': 73, 'worth': 74, 'happi': 75, 'restor': 76, 'charact': 77, 'built': 78, 'minut': 79, 'drive': 80, 'offer': 81, 'across': 82, 'street': 83, 'current': 84, 'rejuven': 85, 'gateway': 86, 'porch': 87, 'place': 88, 'lake': 89, 'love': 90, 'outdoor': 91, 'space': 92, 'good': 93, 'solo': 94, 'busi': 95, 'famili': 96, 'big': 97, 'gorgeous': 98, 'countri': 99, 'set': 100, 'rustic': 101, 'retreat': 102, 'southeast': 103, 'convert': 104, 'modular': 105, 'amen': 106, 'need': 107, 'texa': 108, 'less': 109, 'austin': 110, 'circuit': 111, 'america': 112, 'formula': 113, 'trailer': 114, 'cozi': 115, 'quaint': 116, 'size': 117, 'pet': 118, 'alway': 119, 'share': 120, 'suppli': 121, 'towel': 122, 'shampoo': 123, 'friend': 124, 'first': 125, 'class': 126, 'comfort': 127, 'condo': 128, 'best': 129, 'view': 130, 'bottom': 131, 'deck': 132, 'master': 133, 'step': 134, 'away': 135, 'bayfront': 136, 'entranc': 137, 'histor': 138, 'studio': 139, 'cool': 140, 'apart': 141, 'feel': 142, 'like': 143, 'fit': 144, 'peopl': 145, 'central': 146, 'enjoy': 147, 'gourmet': 148, 'easi': 149, 'major': 150, 'pool': 151, 'gate': 152, 'estat': 153, 'heart': 154, 'dfw': 155, 'wood': 156, 'overlook': 157, 'min': 158, 'field': 159, 'dalla': 160, 'american': 161, 'airlin': 162, 'deep': 163, 'global': 164, 'life': 165, 'six': 166, 'stock': 167, 'motor': 168, 'speed': 169, 'grapevin': 170, 'mill': 171, 'gaylord': 172, 'great': 173, 'wolf': 174, 'check': 175, 'list': 176, 'fabeuless': 177, 'hideaway': 178, 'combin': 179, 'visit': 180, 'also': 181, 'far': 182, 'madden': 183, 'peac': 184, 'die': 185, 'natur': 186, 'spade': 187, 'hum': 188, 'bird': 189, 'come': 190, 'cypress': 191, 'creek': 192, 'hamilton': 193, 'north': 194, 'side': 195, 'golf': 196, 'cours': 197, 'jw': 198, 'marriott': 199, 'resort': 200, 'stop': 201, 'internet': 202, 'laundri': 203, 'green': 204, 'belt': 205, 'back': 206, 'yard': 207, 'area': 208, 'safe': 209, 'neighbor': 210, 'hope': 211, 'pine': 212, 'ceil': 213, 'cottag': 214, 'appeal': 215, 'eclect': 216, 'kerrvill': 217, 'screen': 218, 'huge': 219, 'washer': 220, 'dryer': 221, 'use': 222, 'base': 223, 'explor': 224, 'wine': 225, 'cover': 226, 'carport': 227, 'includ': 228, 'rental': 229, 'get': 230, 'rain': 231, 'bad': 232, 'car': 233, 'new': 234, 'hint': 235, 'bath': 236, 'two': 237, 'lot': 238, 'sunni': 239, 'front': 240, 'ut': 241, 'walk': 242, 'coffe': 243, 'shop': 244, 'cosi': 245, 'hyde': 246, 'restaur': 247, 'ocean': 248, 'getaway': 249, 'magnific': 250, 'plan': 251, 'entertain': 252, 'beltway': 253, 'super': 254, 'bowl': 255, 'bdrm': 256, 'lakefront': 257, 'perfect': 258, 'creat': 259, 'wonder': 260, 'memori': 261, 'right': 262, 'yet': 263, 'relax': 264, 'lewisvill': 265, 'frisco': 266, 'theater': 267, 'plus': 268, 'luxuri': 269, 'nice': 270, 'castleg': 271, 'inch': 272, 'flat': 273, 'live': 274, 'main': 275, 'clean': 276, 'ampl': 277, 'host': 278, 'ping': 279, 'pong': 280, 'tabl': 281, 'garag': 282, 'request': 283, 'group': 284, 'time': 285, 'everyon': 286, ' ...

# %%
invidx = {} # 1: [0,2,5], 245: [1, 4, 7] ->  1: [(0, 1), (2, 3), 5], 245: [1, 4, 7]

for key, value in docdict.items():
    #
    for elem in value:
        if(voc[elem] in invidx):
            invidx[voc[elem]] = invidx[voc[elem]] + [key]
        else:
            invidx[voc[elem]] = [key]
print(invidx)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# def jaccard_sim(list1, list2):
#     a = list1
#     b = list2
#     c = a.intersection(b)
#     return float(len(c))/ len(a) + len(b) - len(c)
def searchJac(string, n):
    languages = {'en': 'english', 'de': 'german', 'es': 'spanish', 'nl': 'dutch'}
    text = string
    lan = detect(str(text))
    if(lan not in languages):
        lan = 'en'
    tostem = ([x.lower() for x in text.split(' ') if x.lower() not in stopwords.words(languages[lan]) and x.isalpha()])
    result = [nltk.stem.SnowballStemmer(languages[lan]).stem(word) for word in tostem]
    
    listofdocs = {}
    for elem in result:
        if(elem in voc):
            if(len(listofdocs) == 0):
                listofdocs = set(invidx[voc[elem]])
            else:
                listofdocs = listofdocs & set(invidx[voc[elem]])
    t = Texttable()
    t.add_row(['Title', 'Description', 'City', 'URL'])
    for elem in listofdocs:
        file_name = DIR + 'doc_'+str(elem)+'.tsv'
        with open(file_name,'rb') as file: # the wb means we are writing a file in binary mode.
            text = str(file.read()).split('\\t')
            t.add_row([text[7], text[4], text[2], text[8]])
            file.close()

    print(t.draw())

# %%
searchJac('Increíble habitación lugares', 10)
# Out:
# +---------------------+---------------------+-------------+--------------------+
# | Title               | Description         | City        | URL                |
# +---------------------+---------------------+-------------+--------------------+
# | Cuarto luminoso     | Lugares de          | Irving      | https://www.airbnb |
# |                     | inter\xc3\xa9s:     |             | .com/rooms/1607339 |
# |                     | transporte          |             | 3?location=Coppell |
# |                     | p\xc3\xbablico,     |             | %2C%20TX\r\n'      |
# |                     | parques. Te va a    |             |                    |
# |                     | encantar mi espacio |             |                    |
# |                     | porque Hay mucho    |             |                    |
# |                     | verde y espacios    |             |                    |
# |                     | con juegos para     |             |                    |
# |                     | ni\xc3\xb1os y      |             |                    |
# |                     | chanchas de futbol. |             |                    |
# |                     | Parrilla y mesas! , |             |                    |
# |                     | La ubicaci\xc3\xb3n |             |                    |
# |                     | es muy buena, es    |             |                    |
# |                     | una zona muy linda  |             |                    |
# |                     | con muchos          |             |                    |
# |                     | restorantes y       |             |                    |
# |                     | supermercados,      |             |                    |
# |                     | farmacias cercas.,  |             |                    |
# |                     | el ambiente Es      |             |                    |
# |                     | agradable.. Mi      |             |                    |
# |                     | alojamiento es      |             |                    |
# |                     | bueno para parejas, |             |                    |
# |                     | aventureros,        |             |                    |
# |                     | viajeros de         |             |                    |
# |                     | negocios y          |             |                    |
# |                     | mascotas.           |             |                    |
# +---------------------+---------------------+-------------+--------------------+
# | House for Rent at   | Lugares de          | Brownsville | https://www.airbnb |
# | Brownsville, Tx.    | inter\xc3\xa9s:     |             | .com/rooms/1664939 |
# |                     | VICC Country Golf   |             | 5?location=Brownsv |
# |                     | Club, Schlitterbahn |             | ille%2C%20TX\r\n'  |
# |                     | Resort Waterpark,   |             |                    |
# |                     | Mercedes Outlet,    |             |                    |
# |                     | Sunrise Mall,       |             |                    |
# |                     | Shopping, South     |             |                    |
# |                     | Padre Island,       |             |                    |
# |                     | ValleyTennis        |             |                    |
# |                     | Center. Te va a     |             |                    |
# |                     | encantar mi espacio |             |                    |
# |                     | por Comodidad,      |             |                    |
# |                     | ubicaci\xc3\xb3n,   |             |                    |
# |                     | acogedor, practico. |             |                    |
# |                     | Mi alojamiento es   |             |                    |
# |                     | bueno para familias |             |                    |
# |                     | (con hijos) y       |             |                    |
# |                     | grupos grandes.     |             |                    |
# +---------------------+---------------------+-------------+--------------------+
# | Peaceful home 25    | Lugares de          | San Antonio | https://www.airbnb |
# | min from Airport    | inter\xc3\xa9s: el  |             | .com/rooms/1577367 |
# | &35 min Downtown    | aeropuerto se       |             | 1?location=Cibolo% |
# |                     | encuentra a 25      |             | 2C%20TX\r\n'       |
# |                     | minutos de          |             |                    |
# |                     | distancia, el       |             |                    |
# |                     | centro de la ciudad |             |                    |
# |                     | se encuentra a 35   |             |                    |
# |                     | min, en el centro   |             |                    |
# |                     | hay mucha vida      |             |                    |
# |                     | nocturna ,          |             |                    |
# |                     | transporte          |             |                    |
# |                     | p\xc3\xbablico a 10 |             |                    |
# |                     | minutos de la casa  |             |                    |
# |                     | hay autobuses que   |             |                    |
# |                     | van a el centro .   |             |                    |
# |                     | Te va a encantar mi |             |                    |
# |                     | lugar debido a los  |             |                    |
# |                     | espacios, y la casa |             |                    |
# |                     | tiene un ambiente   |             |                    |
# |                     | muy acogedor. la    |             |                    |
# |                     | tranquilidad, los   |             |                    |
# |                     | techos altos. Mi    |             |                    |
# |                     | alojamiento es      |             |                    |
# |                     | bueno para viajeros |             |                    |
# |                     | de negocios o       |             |                    |
# |                     | turismo.            |             |                    |
# +---------------------+---------------------+-------------+--------------------+
# | Houston 15 min NRG  | Lugares de          | Houston     | https://www.airbnb |
# |                     | inter\xc3\xa9s:     |             | .com/rooms/1697356 |
# |                     | Hobby airport. Te   |             | 3?location=Channel |
# |                     | va a encantar mi    |             | view%2C%20TX\r\n'  |
# |                     | espacio por         |             |                    |
# |                     | Extremely relax. Mi |             |                    |
# |                     | alojamiento es      |             |                    |
# |                     | bueno para          |             |                    |
# |                     | aventureros y       |             |                    |
# |                     | familias (con       |             |                    |
# |                     | hijos).             |             |                    |
# +---------------------+---------------------+-------------+--------------------+
# | Peaceful home 25    | Lugares de          | San Antonio | https://www.airbnb |
# | min from Airport    | inter\xc3\xa9s: el  |             | .com/rooms/1577367 |
# | &35 min Downtown    | aeropuerto se       |             | 1?location=Bulverd |
# |                     | encuentra a 25      |             | e%2C%20TX\r\n'     |
# |                     | minutos de          |             |                    |
# |                     | distancia, el       |             |                    |
# |                     | centro de la ciudad |             |                    |
# |                     | se encuentra a 35   |             |                    |
# |                     | min, en el centro   |             |                    |
# |                     | hay mucha vida      |             |                    |
# |                     | nocturna ,          |             |                    |
# |                     | transporte          |             |                    |
# |                     | p\xc3\xbablico a 10 |             |                    |
# |                     | minutos de la casa  |             |                    |
# |                     | hay autobuses que   |             |                    |
# |                     | van a el centro .   |             |                    |
# |                     | Te va a encantar mi |             |                    |
# |                     | lugar debido a los  |             |                    |
# |                     | espacios, y la casa |             |                    |
# |                     | tiene un ambiente   |             |                    |
# |                     | muy acogedor. la    |             |                    |
# |                     | tranquilidad, los   |             |                    |
# |                     | techos altos. Mi    |             |                    |
# |                     | alojamiento es      |             |                    |
# |                     | bueno para viajeros |             |                    |
# |                     | de negocios o       |             |                    |
# |                     | turismo.            |             |                    |
# +---------------------+---------------------+-------------+--------------------+
# | Excellent option in | Lugares de          | San Antonio | https://www.airbnb |
# | San Antonio, great  | inter\xc3\xa9s: Six |             | .com/rooms/1452903 |
# | location            | Flags, Sea World,   |             | 4?location=Convers |
# |                     | San Marcos Outlet,  |             | e%2C%20TX\r\n'     |
# |                     | \xc3\x81lamo, San   |             |                    |
# |                     | Antonio downtown. , |             |                    |
# |                     | restaurantes y      |             |                    |
# |                     | comida. Te va a     |             |                    |
# |                     | encantar mi lugar   |             |                    |
# |                     | debido a Su         |             |                    |
# |                     | excelente           |             |                    |
# |                     | ubicaci\xc3\xb3n y  |             |                    |
# |                     | sus espacios, lindo |             |                    |
# |                     | y acogedor.. Mi     |             |                    |
# |                     | alojamiento es      |             |                    |
# |                     | bueno para parejas, |             |                    |
# |                     | viajeros de         |             |                    |
# |                     | negocios y familias |             |                    |
# |                     | (con hijos).        |             |                    |
# +---------------------+---------------------+-------------+--------------------+

# %%
# df.loc[df['language'] == 'es']

# %%
#function tfidf
def tf_idf(word,doc,D,N):
    import math
    f = doc.count(word) / len(doc)
    tfidf = math.log(D/N)*f
    
    return (tfidf)

#function cosine similarity

def cosine_sim(x , y):
    import numpy as np
    
    a = dot(x,y)
    
    b = np.linalg.norm(x)
    c = np.linalg.norm(y)
    
    cos = (a/(b*c))
    
    return (cos)

# %%
# Here I have to create the dictionary with the term ID as key and then the documents where the term id is and also the tfidf.

invidx2 = invidx.copy()
alldocs = []
for key, value in invidx2.items():
    alldocs = alldocs + invidx2[key]
    invidx2[key] = set(value)

Ndocs = len(set(alldocs))
print(Ndocs)
# Out:
# 18156

# %%
inv_voc = {v: k for k, v in voc.items()}
invidx3 = invidx2.copy()

for key, value in invidx2.items():
    tmp = []
    for elem in value:
        file_name = DIR + 'doc_'+str(elem)+'.tsv'
        with open(file_name,'rb') as file: # the wb means we are writing a file in binary mode.
            text = str(file.read()).split('\\t')
            text = text[4].split(' ')
            file.close()
        x = tf_idf(inv_voc[key], text, Ndocs, len(value))
        tmp.append((elem,x))
    invidx3[key] = tmp

print(invidx3)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
print(invidx3[1])
# Out:
# [(0, 0.054217700795021875), (8192, 0.02484977953105169), (8204, 0.11359899214195059), (13, 0.028065633352717202), (16401, 0.07016408338179302), (16403, 0.0), (8215, 0.0), (8218, 0.0), (30, 0.028399748035487647), (16417, 0.029092424816841007), (39, 0.02484977953105169), (46, 0.0), (8240, 0.05679949607097529), (8245, 0.03223755182406706), (8246, 0.030584344038217463), (57, 0.028399748035487647), (8266, 0.028399748035487647), (16462, 0.030584344038217463), (16464, 0.05186040945610788), (16466, 0.08519924410646294), (85, 0.02874191367446943), (8277, 0.06626607874947117), (16475, 0.06626607874947117), (8284, 0.0), (100, 0.06626607874947117), (8294, 0.01579853533099975), (103, 0.03614513386334792), (104, 0.05301286299957694), (8296, 0.0268042565728198), (109, 0.0), (8301, 0.0), (8303, 0.03098154331144107), (16494, 0.06116868807643493), (8315, 0.03359970190114032), (8319, 0.0), (8325, 0.03223755182406706), (8326, 0.05186040945610788), (8335, 0.0), (144, 0.0), (8336, 0.009580637891489809), (146, 0.03098154331144107), (147, 0.03614513386334792), (8338, 0.0), (8345, 0.03727466929657754), (156, 0.2981973543726203), (8350, 0.027108850397510938), (160, 0.05679949607097529), (8355, 0.03098154331144107), (170, 0.0), (175, 0.0), (16562, 0.08226133913727457), (16565, 0.029819735437262032), (8377, 0.0), (197, 0.046776055587862006), (201, 0.03267916212302688), (205, 0.04969955906210338), (8398, 0.0), (16590, 0.0554785775576968), (16593, 0.08226133913727457), (8406, 0.06277839039423584), (8414, 0.0), (8416, 0.0), (8417, 0.03786633071398353), (16609, 0.0), (239, 0.007720319854307322), (8437, 0.029451590555320522), (16630, 0.0), (8440, 0.11636969926736403), (16652, 0.0), (16656, 0.029819735437262032), (275, 0.05679949607097529), (277, 0.03457360630407192), (8473, 0.12233737615286985), (282, 0.0), (8475, 0.06116868807643493), (284, 0.05679949607097529), (8478, 0.03786633071398353), (8479, 0.05301286299957694), (16671, 0.0), (293, 0.0), (8485, 0.03508204169089651), (8486, 0.059639470874524064), (296, 0.03359970190114032), (8491, 0.03019720044279699), (8508, 0.028065633352717202), (16701, 0.014635452975343327), (16702, 0.02874191367446943), (8514, 0.0), (8520, 0.0), (331, 0.0), (8532, 0.03267916212302688), (8533, 0.0), (8534, 0.05679949607097529), (16738, 0.03019720044279699), (8548, 0.03267916212302688), (8552, 0.0), (365, 0.03910784975378627), (8558, 0.0268042565728198), (368, 0.033133039374735586), (369, 0.0), (8562, 0.08519924410646294), (371, 0.059639470874524064), (8567, 0.03267916212302688), (8568, 0.007925511079670971), (378, 0.04969955906210338), (16768, 0.0), (388, 0.06626607874947117), (16774, 0.033133039374735586), (16777, 0.046776055587862006), (396, 0.06116868807643493), (8591, 0.0), (8599, 0.006447510364813412), (16794, 0.0), (418, 0.04969955906210338), (16809, 0.028065633352717202), (429, 0.0277392887788484), (16821, 0.03359970190114032), (8631, 0.0), (16823, 0.03223755182406706), (16824, 0.0277392887788484), (443, 0.054217700795021875), (16827, 0.0), (16832, 0.03098154331144107), (16837, 0.06277839039423584), (8646, 0.02742044637909152), (8653, 0.03910784975378627), (477, 0.0), (16865, 0.07016408338179302), (482, 0.0), (8685, 0.0), (496, 0.013107576016378915), (501, 0.010649905513307868), (8694, 0.0), (503, 0.0), (504, 0.041130669568637285), (8696, 0.00567994960709753), (8699, 0.05186040945610788), (8701, 0.06815939528517036), (510, 0.028399748035487647), (8702, 0.0), (16893, 0.03267916212302688), (518, 0.1835060642293048), (520, 0.054217700795021875), (521, 0.0), (16913, 0.030584344038217463), (8723, 0.030584344038217463), (16918, 0.0), (540, 0.027108850397510938), (542, 0.0), (8735, 0.02742044637909152), (546, 0.03727466929657754), (8740, 0.0), (549, 0.0), (552, 0.06277839039423584), (8746, 0.05818484963368201), (559, 0.06626607874947117), (8755, 0.0554785775576968), (16949, 0.054217700795021875), (16954, 0.0554785775576968), (16962, 0.06626607874947117), (8772, 0.005409475816283362), (8780, 0.004918719247383427), (589, 0.0542177007 ...

# %%
import pickle

# with open(DIR+'dicIndex.json', 'w') as file:
#      file.write(json.dumps(invidx3)) # use `json.loads` to do the reverse
        
with open(DIR+'dicIndex.pkl', 'wb') as file:
        pickle.dump(invidx3, file, pickle.HIGHEST_PROTOCOL)

# %%
def searchCos(string, n):
    with open(DIR+'dicIndex.pkl', 'rb') as file:
        data = pickle.load(file)
    languages = {'en': 'english', 'de': 'german', 'es': 'spanish', 'nl': 'dutch'}
    text = string
    lan = detect(str(text))
    if(lan not in languages):
        lan = 'en'
    tostem = ([x.lower() for x in text.split(' ') if x.lower() not in stopwords.words(languages[lan]) and x.isalpha()])
    result = [nltk.stem.SnowballStemmer(languages[lan]).stem(word) for word in tostem]
    
    listofdocs = {}
    for elem in result:
        if(elem in voc):
            if(len(listofdocs) == 0):
                listofdocs = set(invidx3[voc[elem]])
            else:
                listofdocs = listofdocs & set(invidx3[voc[elem]])
    listofdocs = sorted(list(listofdocs), key=lambda x: -x[1])
    t = Texttable()
    t.add_row(['Title', 'Description', 'City', 'URL'])
    for elem in listofdocs:
        file_name = DIR + 'doc_'+str(elem[0])+'.tsv'
        with open(file_name,'rb') as file: # the wb means we are writing a file in binary mode.
            text = str(file.read()).split('\\t')
            t.add_row([text[7], text[4], text[2], text[8]])
            file.close()

    print(t.draw())

# %%
searchCos('Increíble habitación lugares', 10)
# Out:
# 5477
# 902
# +---------------------+---------------------+-------------+--------------------+
# | Title               | Description         | City        | URL                |
# +---------------------+---------------------+-------------+--------------------+
# | Excellent option in | Lugares de          | San Antonio | https://www.airbnb |
# | San Antonio, great  | inter\xc3\xa9s: Six |             | .com/rooms/1452903 |
# | location            | Flags, Sea World,   |             | 4?location=Convers |
# |                     | San Marcos Outlet,  |             | e%2C%20TX\r\n'     |
# |                     | \xc3\x81lamo, San   |             |                    |
# |                     | Antonio downtown. , |             |                    |
# |                     | restaurantes y      |             |                    |
# |                     | comida. Te va a     |             |                    |
# |                     | encantar mi lugar   |             |                    |
# |                     | debido a Su         |             |                    |
# |                     | excelente           |             |                    |
# |                     | ubicaci\xc3\xb3n y  |             |                    |
# |                     | sus espacios, lindo |             |                    |
# |                     | y acogedor.. Mi     |             |                    |
# |                     | alojamiento es      |             |                    |
# |                     | bueno para parejas, |             |                    |
# |                     | viajeros de         |             |                    |
# |                     | negocios y familias |             |                    |
# |                     | (con hijos).        |             |                    |
# +---------------------+---------------------+-------------+--------------------+
# | Peaceful home 25    | Lugares de          | San Antonio | https://www.airbnb |
# | min from Airport    | inter\xc3\xa9s: el  |             | .com/rooms/1577367 |
# | &35 min Downtown    | aeropuerto se       |             | 1?location=Cibolo% |
# |                     | encuentra a 25      |             | 2C%20TX\r\n'       |
# |                     | minutos de          |             |                    |
# |                     | distancia, el       |             |                    |
# |                     | centro de la ciudad |             |                    |
# |                     | se encuentra a 35   |             |                    |
# |                     | min, en el centro   |             |                    |
# |                     | hay mucha vida      |             |                    |
# |                     | nocturna ,          |             |                    |
# |                     | transporte          |             |                    |
# |                     | p\xc3\xbablico a 10 |             |                    |
# |                     | minutos de la casa  |             |                    |
# |                     | hay autobuses que   |             |                    |
# |                     | van a el centro .   |             |                    |
# |                     | Te va a encantar mi |             |                    |
# |                     | lugar debido a los  |             |                    |
# |                     | espacios, y la casa |             |                    |
# |                     | tiene un ambiente   |             |                    |
# |                     | muy acogedor. la    |             |                    |
# |                     | tranquilidad, los   |             |                    |
# |                     | techos altos. Mi    |             |                    |
# |                     | alojamiento es      |             |                    |
# |                     | bueno para viajeros |             |                    |
# |                     | de negocios o       |             |                    |
# |                     | turismo.            |             |                    |
# +---------------------+---------------------+-------------+--------------------+
# | Peaceful home 25    | Lugares de          | San Antonio | https://www.airbnb |
# | min from Airport    | inter\xc3\xa9s: el  |             | .com/rooms/1577367 |
# | &35 min Downtown    | aeropuerto se       |             | 1?location=Bulverd |
# |                     | encuentra a 25      |             | e%2C%20TX\r\n'     |
# |                     | minutos de          |             |                    |
# |                     | distancia, el       |             |                    |
# |                     | centro de la ciudad |             |                    |
# |                     | se encuentra a 35   |             |                    |
# |                     | min, en el centro   |             |                    |
# |                     | hay mucha vida      |             |                    |
# |                     | nocturna ,          |             |                    |
# |                     | transporte          |             |                    |
# |                     | p\xc3\xbablico a 10 |             |                    |
# |                     | minutos de la casa  |             |                    |
# |                     | hay autobuses que   |             |                    |
# |                     | van a el centro .   |             |                    |
# |                     | Te va a encantar mi |             |                    |
# |                     | lugar debido a los  |             |                    |
# |                     | espacios, y la casa |             |                    |
# |                     | tiene un ambiente   |             |                    |
# |                     | muy acogedor. la    |             |                    |
# |                     | tranquilidad, los   |             |                    |
# |                     | techos altos. Mi    |             |                    |
# |                     | alojamiento es      |             |                    |
# |                     | bueno para viajeros |             |                    |
# |                     | de negocios o       |             |                    |
# |                     | turismo.            |             |                    |
# +---------------------+---------------------+-------------+--------------------+
# | House for Rent at   | Lugares de          | Brownsville | https://www.airbnb |
# | Brownsville, Tx.    | inter\xc3\xa9s:     |             | .com/rooms/1664939 |
# |                     | VICC Country Golf   |             | 5?location=Brownsv |
# |                     | Club, Schlitterbahn |             | ille%2C%20TX\r\n'  |
# |                     | Resort Waterpark,   |             |                    |
# |                     | Mercedes Outlet,    |             |                    |
# |                     | Sunrise Mall,       |             |                    |
# |                     | Shopping, South     |             |                    |
# |                     | Padre Island,       |             |                    |
# |                     | ValleyTennis        |             |                    |
# |                     | Center. Te va a     |             |                    |
# |                     | encantar mi espacio |             |                    |
# |                     | por Comodidad,      |             |                    |
# |                     | ubicaci\xc3\xb3n,   |             |                    |
# |                     | acogedor, practico. |             |                    |
# |                     | Mi alojamiento es   |             |                    |
# |                     | bueno para familias |             |                    |
# |                     | (con hijos) y       |             |                    |
# |                     | grupos grandes.     |             |                    |
# +---------------------+---------------------+-------------+--------------------+
# | Cuarto luminoso     | Lugares de          | Irving      | https://www.airbnb |
# |                     | inter\xc3\xa9s:     |             | .com/rooms/1607339 |
# |                     | transporte          |             | 3?location=Coppell |
# |                     | p\xc3\xbablico,     |             | %2C%20TX\r\n'      |
# |                     | parques. Te va a    |             |                    |
# |                     | encantar mi espacio |             |                    |
# |                     | porque Hay mucho    |             |                    |
# |                     | verde y espacios    |             |                    |
# |                     | con juegos para     |             |                    |
# |                     | ni\xc3\xb1os y      |             |                    |
# |                     | chanchas de futbol. |             |                    |
# |                     | Parrilla y mesas! , |             |                    |
# |                     | La ubicaci\xc3\xb3n |             |                    |
# |                     | es muy buena, es    |             |                    |
# |                     | una zona muy linda  |             |                    |
# |                     | con muchos          |             |                    |
# |                     | restorantes y       |             |                    |
# |                     | supermercados,      |             |                    |
# |                     | farmacias cercas.,  |             |                    |
# |                     | el ambiente Es      |             |                    |
# |                     | agradable.. Mi      |             |                    |
# |                     | alojamiento es      |             |                    |
# |                     | bueno para parejas, |             |                    |
# |                     | aventureros,        |             |                    |
# |                     | viajeros de         |             |                    |
# |                     | negocios y          |             |                    |
# |                     | mascotas.           |             |                    |
# +---------------------+---------------------+-------------+--------------------+
# | Houston 15 min NRG  | Lugares de          | Houston     | https://www.airbnb |
# |                     | inter\xc3\xa9s:     |             | .com/rooms/1697356 |
# |                     | Hobby airport. Te   |             | 3?location=Channel |
# |                     | va a encantar mi    |             | view%2C%20TX\r\n'  |
# |                     | espacio por         |             |                    |
# |                     | Extremely relax. Mi |             |                    |
# |                     | alojamiento es      |             |                    |
# |                     | bueno para          |             |                    |
# |                     | aventureros y       |             |                    |
# |                     | familias (con       |             |                    |
# |                     | hijos).             |             |                    |
# +---------------------+---------------------+-------------+--------------------+
